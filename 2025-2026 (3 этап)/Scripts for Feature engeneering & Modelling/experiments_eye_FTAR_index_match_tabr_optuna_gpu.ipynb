# %% [markdown]
# # Eye tracking + text2text + TabR (Optuna, GPU)
#
# This notebook mirrors the structure of `experiments_eye_text2text_index_match.ipynb`, but replaces tree models with a **TabR-style retrieval-augmented tabular deep model** trained on **GPU** and tuned with **Optuna**.
#
# Main differences from the original notebook:
# - uses a **TabR-like PyTorch model** instead of XGBoost / CatBoost
# - tunes **model parameters and training parameters jointly**
# - runs **grouped CV** on the training split
# - saves each experiment to a **separate folder**
# - keeps the same **eye-tracking + text2text index-matching** logic
#
# Notes:
# - the implementation is intentionally self-contained inside the notebook
# - retrieval is performed on GPU with PyTorch tensors
# - the code assumes all features are numerical after preprocessing / concatenation

# %%
from __future__ import annotations

import os
import gc
import json
import math
import random
from copy import deepcopy
from pathlib import Path
from typing import Dict, Tuple, Optional, List

import numpy as np
import pandas as pd
from umap import UMAP

import optuna
from optuna.samplers import TPESampler

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import f1_score, accuracy_score
from sklearn.model_selection import GroupKFold, StratifiedKFold

from experiment_code.read_data import get_data_for_split
from experiment_code.run_experiments import _build_groups_mm_for_mm


# Data root: contains datasets_splitted_screen_match_mismatch*
ROOT = Path(r"C:\Users\LEGION\data\СB")
os.chdir(ROOT)
print("cwd:", Path.cwd())

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", DEVICE)
if DEVICE.type == "cuda":
    print("cuda:", torch.cuda.get_device_name(0))
# Out:
# cwd: C:\Users\LEGION\data\СB
# device: cuda
# cuda: NVIDIA GeForce RTX 4080 Laptop GPU

# %%
# Main settings
TARGETS = ["match_mismatch", "match_mismatch_general"]
SPLITS = ["binary", "multiclass"]

CV = 4
N_TRIALS_TABR = 60
RANDOM_STATE = 42

USE_UMAP_FOR = {"freq_bands", "stat", "corr", "cov_freq"}
UMAP_N_COMPONENTS = 100
CLEAN_TRAIN_COLUMNS = False

MAX_EPOCHS_DEFAULT = 100
EARLY_STOPPING_PATIENCE_DEFAULT = 20
N_WORKERS = 0

# Output location under project folder
PROJECT_DIR = Path(r"C:\Users\LEGION\Projects\CB_exepriment\dataset_v2")
OUT_DIR = PROJECT_DIR / "optuna_results_eye_FTAR_tabr"
OUT_DIR.mkdir(parents=True, exist_ok=True)

MODELS_DIR = OUT_DIR / "models"
MODELS_DIR.mkdir(parents=True, exist_ok=True)

TRIALS_DIR = OUT_DIR / "optuna_trials"
TRIALS_DIR.mkdir(parents=True, exist_ok=True)

PREDS_DIR = OUT_DIR / "predictions"
PREDS_DIR.mkdir(parents=True, exist_ok=True)

SUMMARY_DIR = OUT_DIR / "summaries"
SUMMARY_DIR.mkdir(parents=True, exist_ok=True)

FTAR_DIR = Path(r"C:\Users\LEGION\Projects\CB_exepriment\ftar_features")
FTAR_FILES = {
    "corr": FTAR_DIR / "corr.parquet",
    "cov_freq": FTAR_DIR / "cov_freq.parquet",
    "envelope": FTAR_DIR / "envelope.parquet",
    "freq_bands": FTAR_DIR / "freq_bands.parquet",
    "PID": FTAR_DIR / "PID.parquet",
    "stat": FTAR_DIR / "stat.parquet",
}

# %%
def seed_everything(seed: int = RANDOM_STATE) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)


def _prefix_cols(df: pd.DataFrame, prefix: str) -> pd.DataFrame:
    return df.add_prefix(prefix)


def _load_text2text_parquet(path: Path) -> pd.DataFrame:
    df = pd.read_parquet(path)
    if "pid_rn" not in df.columns:
        raise KeyError(f"'pid_rn' column not found in {path}")
    df = df.set_index("pid_rn")
    df.index = df.index.astype(str)
    return df


def _apply_umap_train_test(
    text_train: pd.DataFrame,
    text_test: pd.DataFrame,
    *,
    text_set_name: str,
) -> tuple[pd.DataFrame, pd.DataFrame]:
    tr = text_train.apply(pd.to_numeric, errors="coerce")
    te = text_test.apply(pd.to_numeric, errors="coerce")

    train_means = tr.mean(numeric_only=True)
    tr = tr.fillna(train_means).fillna(0.0)
    te = te.fillna(train_means).fillna(0.0)

    n_components = int(min(UMAP_N_COMPONENTS, max(2, tr.shape[1])))
    reducer = UMAP(n_components=n_components, random_state=RANDOM_STATE)

    print(
        f"[{text_set_name}] UMAP compression: "
        f"train/test features {tr.shape[1]} -> {n_components}"
    )

    z_train = reducer.fit_transform(tr)
    z_test = reducer.transform(te)

    cols = [f"{text_set_name}__umap_{i:03d}" for i in range(n_components)]
    tr_umap = pd.DataFrame(z_train, index=text_train.index, columns=cols)
    te_umap = pd.DataFrame(z_test, index=text_test.index, columns=cols)
    return tr_umap, te_umap


def _prepare_joined_X(
    eye_train: pd.DataFrame,
    eye_test: pd.DataFrame,
    text_all: pd.DataFrame,
    text_set_name: str,
) -> Tuple[pd.DataFrame, pd.DataFrame]:
    text_train = text_all.reindex(eye_train.index)
    text_test = text_all.reindex(eye_test.index)

    missing_train = int(text_train.isna().all(axis=1).sum())
    missing_test = int(text_test.isna().all(axis=1).sum())
    print(f"[{text_set_name}] rows missing after index match -> train: {missing_train}, test: {missing_test}")

    if text_set_name in USE_UMAP_FOR:
        text_train_model, text_test_model = _apply_umap_train_test(
            text_train,
            text_test,
            text_set_name=text_set_name,
        )
    else:
        text_train_model = _prefix_cols(text_train, f"{text_set_name}__")
        text_test_model = _prefix_cols(text_test, f"{text_set_name}__")

    X_train = pd.concat([
        _prefix_cols(eye_train, "eye__"),
        text_train_model,
    ], axis=1)
    X_test = pd.concat([
        _prefix_cols(eye_test, "eye__"),
        text_test_model,
    ], axis=1)

    if CLEAN_TRAIN_COLUMNS:
        keep_cols = X_train.columns[X_train.notna().all(axis=0)]
        X_train = X_train[keep_cols]
        X_test = X_test.reindex(columns=keep_cols)

    # numeric-only, fit preprocessing on train only
    X_train = X_train.apply(pd.to_numeric, errors="coerce")
    X_test = X_test.apply(pd.to_numeric, errors="coerce")

    means = X_train.mean(axis=0)
    stds = X_train.std(axis=0).replace(0.0, 1.0)

    X_train = X_train.fillna(means).fillna(0.0)
    X_test = X_test.fillna(means).fillna(0.0)

    X_train = (X_train - means) / stds
    X_test = (X_test - means) / stds

    X_train = X_train.replace([np.inf, -np.inf], 0.0)
    X_test = X_test.replace([np.inf, -np.inf], 0.0)

    return X_train.astype(np.float32), X_test.astype(np.float32)


def _build_no_neutral_mask(stim_df: pd.DataFrame, target: str, split: str) -> pd.Series:
    mask = pd.Series(True, index=stim_df.index)

    if "valence" in stim_df.columns:
        valence = pd.to_numeric(stim_df["valence"], errors="coerce")
        mask &= valence != 2

    if split == "binary":
        if target == "match_mismatch_general" and "exp_general_multi" in stim_df.columns:
            exp_general_multi = pd.to_numeric(stim_df["exp_general_multi"], errors="coerce")
            mask &= exp_general_multi != 2
        elif "IAT_results2" in stim_df.columns:
            iat = stim_df["IAT_results2"].astype(str).str.strip().str.lower()
            mask &= iat != "neutral"

    return mask.fillna(False)


def _load_eye_for_task(target: str, split: str, no_neutral: bool = False):
    df, tgt, _ = get_data_for_split(X_name="screen", target=target, split=split)

    eye_train = df["all_features"]["X_train"].copy()
    eye_test = df["all_features"]["X_test"].copy()
    stim_train = df["stimuli_features"]["X_train"].copy()
    stim_test = df["stimuli_features"]["X_test"].copy()

    y_train = tgt["cb"]["y_train"].copy()
    y_test = tgt["cb"]["y_test"].copy()

    if no_neutral:
        mask_train = _build_no_neutral_mask(stim_train, target=target, split=split)
        mask_test = _build_no_neutral_mask(stim_test, target=target, split=split)

        eye_train = eye_train.loc[mask_train]
        eye_test = eye_test.loc[mask_test]
        y_train = y_train.loc[mask_train]
        y_test = y_test.loc[mask_test]
        stim_train = stim_train.loc[mask_train]

    groups = np.array([str(i).split("_")[0] for i in eye_train.index])

    if target in ("match_mismatch", "match_mismatch_general"):
        groups_mm = _build_groups_mm_for_mm(X_train_index=eye_train.index, stim_train_df=stim_train)
    else:
        groups_mm = None

    problem = "binary" if split == "binary" else "multiclass"
    return eye_train, eye_test, y_train, y_test, groups, groups_mm, problem

# %%
class NumpyTabularDataset(Dataset):
    def __init__(self, X: np.ndarray, y: np.ndarray):
        self.X = torch.tensor(X, dtype=torch.float32)
        if y.ndim != 1:
            y = y.reshape(-1)
        self.y = torch.tensor(y)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


class TabRModel(nn.Module):
    """
    Simplified TabR-style model for numerical tabular data.

    Architecture:
    1. encoder -> latent representation z
    2. key projection for retrieval
    3. retrieve top-k neighbours from candidate set (train fold)
    4. aggregate label-aware context
    5. predictor head

    Designed to stay close in spirit to the official TabR structure while being
    self-contained and easy to tune in a notebook.
    """
    def __init__(
        self,
        input_dim: int,
        n_classes: int,
        d_main: int = 256,
        d_block: int = 512,
        encoder_n_blocks: int = 2,
        predictor_n_blocks: int = 2,
        context_dropout: float = 0.1,
        dropout0: float = 0.1,
        dropout1: float = 0.1,
        normalization: str = "LayerNorm",
        activation: str = "ReLU",
        k_neighbors: int = 32,
        label_smoothing: float = 0.0,
    ):
        super().__init__()
        self.n_classes = n_classes
        self.k_neighbors = k_neighbors
        self.label_smoothing = label_smoothing

        Norm = getattr(nn, normalization)
        Act = getattr(nn, activation)

        self.input = nn.Linear(input_dim, d_main)

        def make_block():
            return nn.Sequential(
                Norm(d_main),
                nn.Linear(d_main, d_block),
                Act(),
                nn.Dropout(dropout0),
                nn.Linear(d_block, d_main),
                nn.Dropout(dropout1),
            )

        self.encoder_blocks = nn.ModuleList([make_block() for _ in range(encoder_n_blocks)])
        self.norm_before_retrieval = Norm(d_main)
        self.key_proj = nn.Linear(d_main, d_main)
        self.context_transform = nn.Sequential(
            nn.Linear(d_main, d_block),
            Act(),
            nn.Dropout(dropout0),
            nn.Linear(d_block, d_main, bias=False),
        )
        self.context_dropout = nn.Dropout(context_dropout)

        self.label_encoder = nn.Embedding(n_classes, d_main)

        self.predictor_blocks = nn.ModuleList([make_block() for _ in range(predictor_n_blocks)])
        self.head = nn.Sequential(
            Norm(d_main),
            Act(),
            nn.Linear(d_main, n_classes),
        )

    def encode(self, x: torch.Tensor):
        z = self.input(x)
        for block in self.encoder_blocks:
            z = z + block(z)
        k = self.key_proj(self.norm_before_retrieval(z))
        return z, k

    def retrieve_context(
        self,
        query_k: torch.Tensor,
        cand_z: torch.Tensor,
        cand_k: torch.Tensor,
        cand_y: torch.Tensor,
    ) -> torch.Tensor:
        # negative squared distance
        # shapes: query [B, D], cand [N, D]
        # gpu-friendly exact retrieval for moderate-size folds
        q2 = (query_k ** 2).sum(dim=1, keepdim=True)          # [B, 1]
        c2 = (cand_k ** 2).sum(dim=1).unsqueeze(0)            # [1, N]
        sim = -(q2 - 2.0 * query_k @ cand_k.T + c2)          # [B, N]

        k = min(self.k_neighbors, cand_k.shape[0])
        top_sim, top_idx = torch.topk(sim, k=k, dim=1)

        probs = F.softmax(top_sim, dim=1)
        probs = self.context_dropout(probs)

        neigh_z = cand_z[top_idx]                            # [B, k, D]
        neigh_y = cand_y[top_idx]                            # [B, k]
        neigh_y_emb = self.label_encoder(neigh_y)            # [B, k, D]

        values = neigh_y_emb + self.context_transform(query_k[:, None, :] - neigh_z)
        context = (probs.unsqueeze(1) @ values).squeeze(1)   # [B, D]
        return context

    def forward(
        self,
        x: torch.Tensor,
        candidate_x: torch.Tensor,
        candidate_y: torch.Tensor,
    ) -> torch.Tensor:
        z, k = self.encode(x)
        cand_z, cand_k = self.encode(candidate_x)
        context = self.retrieve_context(k, cand_z, cand_k, candidate_y)
        h = z + context
        for block in self.predictor_blocks:
            h = h + block(h)
        return self.head(h)

# %%
def make_loaders(X_train, y_train, batch_size, shuffle=True):
    ds = NumpyTabularDataset(X_train, y_train)
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=N_WORKERS,
        pin_memory=(DEVICE.type == "cuda"),
        drop_last=False,
    )


def predict_proba_tabr(
    model: nn.Module,
    X_eval: np.ndarray,
    X_candidates: np.ndarray,
    y_candidates: np.ndarray,
    batch_size: int = 1024,
) -> np.ndarray:
    model.eval()

    X_cand_t = torch.tensor(X_candidates, dtype=torch.float32, device=DEVICE)
    y_cand_t = torch.tensor(y_candidates, dtype=torch.long, device=DEVICE)

    all_logits = []
    with torch.no_grad():
        for start in range(0, len(X_eval), batch_size):
            xb = torch.tensor(X_eval[start:start+batch_size], dtype=torch.float32, device=DEVICE)
            logits = model(xb, X_cand_t, y_cand_t)
            all_logits.append(logits.detach().cpu())
    logits = torch.cat(all_logits, dim=0)
    probs = torch.softmax(logits, dim=1).numpy()
    return probs


def compute_metrics(y_true, y_pred):
    return {
        "accuracy": float(accuracy_score(y_true, y_pred)),
        "macro_f1": float(f1_score(y_true, y_pred, average="macro")),
    }


def train_one_fold(
    X_tr: np.ndarray,
    y_tr: np.ndarray,
    X_val: np.ndarray,
    y_val: np.ndarray,
    params: dict,
    seed: int = RANDOM_STATE,
):
    seed_everything(seed)

    model = TabRModel(
        input_dim=X_tr.shape[1],
        n_classes=int(len(np.unique(y_tr))),
        d_main=params["d_main"],
        d_block=params["d_block"],
        encoder_n_blocks=params["encoder_n_blocks"],
        predictor_n_blocks=params["predictor_n_blocks"],
        context_dropout=params["context_dropout"],
        dropout0=params["dropout0"],
        dropout1=params["dropout1"],
        normalization=params["normalization"],
        activation=params["activation"],
        k_neighbors=params["k_neighbors"],
        label_smoothing=params["label_smoothing"],
    ).to(DEVICE)

    optimizer_name = params["optimizer"]
    lr = params["lr"]
    weight_decay = params["weight_decay"]

    if optimizer_name == "adamw":
        optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    elif optimizer_name == "adam":
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    else:
        optimizer = torch.optim.RAdam(model.parameters(), lr=lr, weight_decay=weight_decay)

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="max",
        factor=0.5,
        patience=max(4, params["patience"] // 3),
    )

    criterion = nn.CrossEntropyLoss(label_smoothing=params["label_smoothing"])

    loader = make_loaders(X_tr, y_tr, params["batch_size"], shuffle=True)

    X_tr_t = torch.tensor(X_tr, dtype=torch.float32, device=DEVICE)
    y_tr_t = torch.tensor(y_tr, dtype=torch.long, device=DEVICE)

    best_state = None
    best_score = -np.inf
    best_epoch = -1
    no_improve = 0
    history = []

    for epoch in range(params["max_epochs"]):
        model.train()
        epoch_losses = []

        for xb, yb in loader:
            xb = xb.to(DEVICE, non_blocking=True)
            yb = yb.to(DEVICE, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)
            logits = model(xb, X_tr_t, y_tr_t)
            loss = criterion(logits, yb)
            loss.backward()

            if params["grad_clip"] is not None:
                torch.nn.utils.clip_grad_norm_(model.parameters(), params["grad_clip"])

            optimizer.step()
            epoch_losses.append(loss.item())

        val_probs = predict_proba_tabr(
            model=model,
            X_eval=X_val,
            X_candidates=X_tr,
            y_candidates=y_tr,
            batch_size=params["eval_batch_size"],
        )
        val_pred = val_probs.argmax(axis=1)
        val_metrics = compute_metrics(y_val, val_pred)
        val_score = val_metrics["macro_f1"]
        scheduler.step(val_score)

        history.append({
            "epoch": epoch,
            "train_loss": float(np.mean(epoch_losses)),
            **{f"val_{k}": v for k, v in val_metrics.items()}
        })

        if val_score > best_score:
            best_score = val_score
            best_epoch = epoch
            best_state = deepcopy(model.state_dict())
            no_improve = 0
        else:
            no_improve += 1

        if no_improve >= params["patience"]:
            break

    if best_state is None:
        raise RuntimeError("Training finished without a best checkpoint.")

    model.load_state_dict(best_state)
    return model, best_score, best_epoch, history

# %%
def suggest_tabr_params(trial: optuna.Trial, n_features: int, n_classes: int) -> dict:
    d_main = trial.suggest_categorical("d_main", [128, 192, 256, 384, 512])
    d_mult = trial.suggest_categorical("d_mult", [1.5, 2.0, 2.5, 3.0, 4.0])

    params = {
        # model
        "d_main": d_main,
        "d_block": int(d_main * d_mult),
        "encoder_n_blocks": trial.suggest_int("encoder_n_blocks", 1, 4),
        "predictor_n_blocks": trial.suggest_int("predictor_n_blocks", 1, 4),
        "context_dropout": trial.suggest_float("context_dropout", 0.0, 0.4),
        "dropout0": trial.suggest_float("dropout0", 0.0, 0.4),
        "dropout1": trial.suggest_float("dropout1", 0.0, 0.4),
        "normalization": trial.suggest_categorical("normalization", ["LayerNorm"]),
        "activation": trial.suggest_categorical("activation", ["ReLU", "GELU"]),
        "k_neighbors": trial.suggest_categorical("k_neighbors", [8, 16, 24, 32, 48, 64]),

        # training
        "optimizer": trial.suggest_categorical("optimizer", ["adamw", "adam", "radam"]),
        "lr": trial.suggest_float("lr", 1e-4, 5e-3, log=True),
        "weight_decay": trial.suggest_float("weight_decay", 1e-6, 5e-3, log=True),
        "batch_size": trial.suggest_categorical("batch_size", [128, 256, 512, 1024]),
        "eval_batch_size": trial.suggest_categorical("eval_batch_size", [256, 512, 1024, 2048]),
        "max_epochs": trial.suggest_int("max_epochs", 80, MAX_EPOCHS_DEFAULT),
        "patience": trial.suggest_int("patience", 12, EARLY_STOPPING_PATIENCE_DEFAULT),
        "grad_clip": trial.suggest_categorical("grad_clip", [None, 1.0, 2.0, 5.0]),
        "label_smoothing": trial.suggest_float("label_smoothing", 0.0, 0.1),
    }
    return params


def run_cv_optuna(
    X: pd.DataFrame,
    y: pd.Series,
    groups: np.ndarray,
    *,
    study_name: str,
    n_trials: int = N_TRIALS_TABR,
    cv: int = CV,
    seed: int = RANDOM_STATE,
):
    X_np = X.to_numpy(dtype=np.float32)
    y_np = np.asarray(y).astype(int)

    def objective(trial: optuna.Trial) -> float:
        params = suggest_tabr_params(trial, n_features=X_np.shape[1], n_classes=len(np.unique(y_np)))
        splitter = GroupKFold(n_splits=cv)

        fold_scores = []
        for fold_idx, (tr_idx, va_idx) in enumerate(splitter.split(X_np, y_np, groups=groups)):
            X_tr, X_va = X_np[tr_idx], X_np[va_idx]
            y_tr, y_va = y_np[tr_idx], y_np[va_idx]

            model, best_score, best_epoch, history = train_one_fold(
                X_tr=X_tr,
                y_tr=y_tr,
                X_val=X_va,
                y_val=y_va,
                params=params,
                seed=seed + fold_idx,
            )
            fold_scores.append(best_score)

            trial.report(np.mean(fold_scores), step=fold_idx)
            if trial.should_prune():
                raise optuna.TrialPruned()

            del model
            gc.collect()
            if DEVICE.type == "cuda":
                torch.cuda.empty_cache()

        return float(np.mean(fold_scores))

    sampler = TPESampler(seed=seed, multivariate=True)
    study = optuna.create_study(
        direction="maximize",
        study_name=study_name,
        sampler=sampler,
    )
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

    trials_df = study.trials_dataframe()
    return study, trials_df

# %%
def fit_best_and_test_tabr(
    X_train: pd.DataFrame,
    y_train: pd.Series,
    X_test: pd.DataFrame,
    y_test: pd.Series,
    best_params: dict,
    *,
    seed: int = RANDOM_STATE,
):
    X_train_np = X_train.to_numpy(dtype=np.float32)
    X_test_np = X_test.to_numpy(dtype=np.float32)
    y_train_np = np.asarray(y_train).astype(int)
    y_test_np = np.asarray(y_test).astype(int)

    # hold out a small validation part from train for early stopping
    val_splitter = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    tr_idx, va_idx = next(val_splitter.split(X_train_np, y_train_np))

    X_tr, X_va = X_train_np[tr_idx], X_train_np[va_idx]
    y_tr, y_va = y_train_np[tr_idx], y_train_np[va_idx]

    model, best_score, best_epoch, history = train_one_fold(
        X_tr=X_tr,
        y_tr=y_tr,
        X_val=X_va,
        y_val=y_va,
        params=best_params,
        seed=seed,
    )

    test_probs = predict_proba_tabr(
        model=model,
        X_eval=X_test_np,
        X_candidates=X_train_np,
        y_candidates=y_train_np,
        batch_size=best_params["eval_batch_size"],
    )
    test_pred = test_probs.argmax(axis=1)
    test_metrics = compute_metrics(y_test_np, test_pred)

    return {
        "model": model,
        "best_score_internal_val": float(best_score),
        "best_epoch": int(best_epoch),
        "history": history,
        "test_metrics": test_metrics,
        "test_pred": test_pred,
        "test_probs": test_probs,
    }

# %%
def run_FTAR_set_tabr(
    text_set_name: str,
    text_all: pd.DataFrame,
    *,
    n_trials: int = N_TRIALS_TABR,
    do_test_fit: bool = True,
):
    if "pid_rn" in text_all.columns:
        text_all = text_all.set_index("pid_rn")
    text_all = text_all.copy()
    text_all.index = text_all.index.astype(str)

    if "key" in text_all.columns:
        text_all = text_all.drop(columns=["key"])

    text_features = int(text_all.shape[1])
    print(f"[{text_set_name}] text2text feature count after cleanup: {text_features}")

    rows = []

    for target in TARGETS:
        for split in SPLITS:
            for no_neutral in [False, True]:
                problem = "binary" if split == "binary" else "multiclass"
                neutral_suffix = "__no_neutral" if no_neutral else ""
                exp_name = (
                    f"tabr__X_name=screen+{text_set_name}"
                    f"__target={target}"
                    f"__problem={problem}"
                    f"__feat=all_features+{text_set_name}"
                    f"__gpu_optuna"
                    f"{neutral_suffix}"
                )
                exp_dir = OUT_DIR / exp_name
                exp_dir.mkdir(parents=True, exist_ok=True)

                report_path = exp_dir / "report.json"
                if report_path.exists():
                    print("\n" + "=" * 80)
                    print(f"Skipping existing experiment: {exp_name}")
                    with open(report_path, "r", encoding="utf-8") as f:
                        report = json.load(f)
                    rows.append({
                        "text_set": text_set_name,
                        "target": target,
                        "split": split,
                        "no_neutral": no_neutral,
                        "tabr_test_macro_f1": report["test_metrics"]["macro_f1"],
                        "tabr_test_accuracy": report["test_metrics"]["accuracy"],
                        "file": str(report_path),
                    })
                    continue

                eye_train, eye_test, y_train, y_test, groups, groups_mm, problem = _load_eye_for_task(
                    target,
                    split,
                    no_neutral=no_neutral,
                )
                X_train, X_test = _prepare_joined_X(eye_train, eye_test, text_all, text_set_name)

                print("\n" + "=" * 80)
                print(f"Running: {exp_name}")
                print(f"X_train: {X_train.shape}, X_test: {X_test.shape}")

                study, trials_df = run_cv_optuna(
                    X=X_train,
                    y=y_train,
                    groups=groups,
                    study_name=exp_name,
                    n_trials=n_trials,
                    cv=CV,
                    seed=RANDOM_STATE,
                )

                best_params = study.best_trial.params
                if "d_block" not in best_params:
                    best_params["d_block"] = int(best_params["d_main"] * best_params["d_mult"])
                with open(exp_dir / "best_params.json", "w", encoding="utf-8") as f:
                    json.dump(best_params, f, indent=2, ensure_ascii=False)

                trials_df.to_csv(exp_dir / "optuna_trials.csv", index=False)

                final_out = fit_best_and_test_tabr(
                    X_train=X_train,
                    y_train=y_train,
                    X_test=X_test,
                    y_test=y_test,
                    best_params=best_params,
                    seed=RANDOM_STATE,
                )

                pred_df = pd.DataFrame({
                    "index": X_test.index.astype(str),
                    "y_true": np.asarray(y_test).astype(int),
                    "y_pred": final_out["test_pred"].astype(int),
                })
                for i in range(final_out["test_probs"].shape[1]):
                    pred_df[f"proba_{i}"] = final_out["test_probs"][:, i]
                pred_df.to_csv(exp_dir / "test_predictions.csv", index=False)

                torch.save(final_out["model"].state_dict(), exp_dir / "tabr_model.pt")

                report = {
                    "experiment_name": exp_name,
                    "text_set": text_set_name,
                    "target": target,
                    "split": split,
                    "problem": problem,
                    "n_train": int(X_train.shape[0]),
                    "n_test": int(X_test.shape[0]),
                    "n_features": int(X_train.shape[1]),
                    "device": str(DEVICE),
                    "best_trial_number": int(study.best_trial.number),
                    "best_cv_macro_f1": float(study.best_value),
                    "best_params": best_params,
                    "best_epoch_internal_val": int(final_out["best_epoch"]),
                    "test_metrics": final_out["test_metrics"],
                    "report_file": str(report_path),
                }

                with open(report_path, "w", encoding="utf-8") as f:
                    json.dump(report, f, indent=2, ensure_ascii=False)

                rows.append({
                    "text_set": text_set_name,
                    "target": target,
                    "split": split,
                    "no_neutral": no_neutral,
                    "tabr_test_macro_f1": float(final_out["test_metrics"]["macro_f1"]),
                    "tabr_test_accuracy": float(final_out["test_metrics"]["accuracy"]),
                    "file": str(report_path),
                })

                del final_out
                gc.collect()
                if DEVICE.type == "cuda":
                    torch.cuda.empty_cache()

    summary = pd.DataFrame(rows)
    display(summary)
    return summary

# %%
print("text2text dir:", FTAR_DIR)
for k, p in FTAR_FILES.items():
    print(f"{k:10s} -> {p} | exists={p.exists()}")
    if p.exists():
        print(pd.read_parquet(p).shape)
# Out:
# text2text dir: C:\Users\LEGION\Projects\CB_exepriment\ftar_features
# corr       -> C:\Users\LEGION\Projects\CB_exepriment\ftar_features\corr.parquet | exists=True
# (4442, 1832)
# cov_freq   -> C:\Users\LEGION\Projects\CB_exepriment\ftar_features\cov_freq.parquet | exists=True
# (4442, 36297)
# envelope   -> C:\Users\LEGION\Projects\CB_exepriment\ftar_features\envelope.parquet | exists=True
# (4442, 429)
# freq_bands -> C:\Users\LEGION\Projects\CB_exepriment\ftar_features\freq_bands.parquet | exists=True
# (4442, 18363)
# PID        -> C:\Users\LEGION\Projects\CB_exepriment\ftar_features\PID.parquet | exists=True
# (4442, 612)
# stat       -> C:\Users\LEGION\Projects\CB_exepriment\ftar_features\stat.parquet | exists=True
# (4442, 8237)

# %%
# Set: corr
text_corr = pd.read_parquet(FTAR_FILES["corr"])
print("corr shape:", text_corr.shape)
summary_corr = run_FTAR_set_tabr("corr", text_corr)
summary_corr
# Out:
# corr shape: (4442, 1832)
# [corr] text2text feature count after cleanup: 1830
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+corr__target=match_mismatch__problem=binary__feat=all_features+corr__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+corr__target=match_mismatch__problem=binary__feat=all_features+corr__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+corr__target=match_mismatch__problem=multiclass__feat=all_features+corr__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+corr__target=match_mismatch__problem=multiclass__feat=all_features+corr__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+corr__target=match_mismatch_general__problem=binary__feat=all_features+corr__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+corr__target=match_mismatch_general__problem=binary__feat=all_features+corr__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+corr__target=match_mismatch_general__problem=multiclass__feat=all_features+corr__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+corr__target=match_mismatch_general__problem=multiclass__feat=all_features+corr__gpu_optuna__no_neutral
#   text_set                  target       split  no_neutral  \
# 0     corr          match_mismatch      binary       False
# 1     corr          match_mismatch      binary        True
# 2     corr          match_mismatch  multiclass       False
# 3     corr          match_mismatch  multiclass        True
# 4     corr  match_mismatch_general      binary       False
# 5     corr  match_mismatch_general      binary        True
# 6     corr  match_mismatch_general  multiclass       False
# 7     corr  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.491072            0.553145
# 1            0.477785            0.553571
# 2            0.597854            0.583514
# 3            0.467521            0.470238
# 4            0.518002            0.561822
# 5            0.553320            0.574405
# 6            0.670284            0.663774
# 7            0.571413            0.571429
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...
#   text_set                  target       split  no_neutral  \
# 0     corr          match_mismatch      binary       False
# 1     corr          match_mismatch      binary        True
# 2     corr          match_mismatch  multiclass       False
# 3     corr          match_mismatch  multiclass        True
# 4     corr  match_mismatch_general      binary       False
# 5     corr  match_mismatch_general      binary        True
# 6     corr  match_mismatch_general  multiclass       False
# 7     corr  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.491072            0.553145
# 1            0.477785            0.553571
# 2            0.597854            0.583514
# 3            0.467521            0.470238
# 4            0.518002            0.561822
# 5            0.553320            0.574405
# 6            0.670284            0.663774
# 7            0.571413            0.571429
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...

# %%
# Set: cov_freq
text_cov_freq = pd.read_parquet(FTAR_FILES["cov_freq"])
print("cov_freq shape:", text_cov_freq.shape)
summary_cov_freq = run_FTAR_set_tabr("cov_freq", text_cov_freq)
summary_cov_freq
# Out:
# cov_freq shape: (4442, 36297)
# [cov_freq] text2text feature count after cleanup: 36295
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+cov_freq__target=match_mismatch__problem=binary__feat=all_features+cov_freq__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+cov_freq__target=match_mismatch__problem=binary__feat=all_features+cov_freq__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+cov_freq__target=match_mismatch__problem=multiclass__feat=all_features+cov_freq__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+cov_freq__target=match_mismatch__problem=multiclass__feat=all_features+cov_freq__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+cov_freq__target=match_mismatch_general__problem=binary__feat=all_features+cov_freq__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+cov_freq__target=match_mismatch_general__problem=binary__feat=all_features+cov_freq__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+cov_freq__target=match_mismatch_general__problem=multiclass__feat=all_features+cov_freq__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+cov_freq__target=match_mismatch_general__problem=multiclass__feat=all_features+cov_freq__gpu_optuna__no_neutral
#    text_set                  target       split  no_neutral  \
# 0  cov_freq          match_mismatch      binary       False
# 1  cov_freq          match_mismatch      binary        True
# 2  cov_freq          match_mismatch  multiclass       False
# 3  cov_freq          match_mismatch  multiclass        True
# 4  cov_freq  match_mismatch_general      binary       False
# 5  cov_freq  match_mismatch_general      binary        True
# 6  cov_freq  match_mismatch_general  multiclass       False
# 7  cov_freq  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.497442            0.561822
# 1            0.454478            0.645833
# 2            0.548873            0.531453
# 3            0.513636            0.514881
# 4            0.502243            0.548807
# 5            0.529539            0.630952
# 6            0.649750            0.642082
# 7            0.523234            0.526786
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...
#    text_set                  target       split  no_neutral  \
# 0  cov_freq          match_mismatch      binary       False
# 1  cov_freq          match_mismatch      binary        True
# 2  cov_freq          match_mismatch  multiclass       False
# 3  cov_freq          match_mismatch  multiclass        True
# 4  cov_freq  match_mismatch_general      binary       False
# 5  cov_freq  match_mismatch_general      binary        True
# 6  cov_freq  match_mismatch_general  multiclass       False
# 7  cov_freq  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.497442            0.561822
# 1            0.454478            0.645833
# 2            0.548873            0.531453
# 3            0.513636            0.514881
# 4            0.502243            0.548807
# 5            0.529539            0.630952
# 6            0.649750            0.642082
# 7            0.523234            0.526786
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...

# %%
# Set: envelope
text_envelope = pd.read_parquet(FTAR_FILES["envelope"])
print("envelope shape:", text_envelope.shape)
summary_envelope = run_FTAR_set_tabr("envelope", text_envelope)
summary_envelope
# Out:
# envelope shape: (4442, 429)
# [envelope] text2text feature count after cleanup: 427
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+envelope__target=match_mismatch__problem=binary__feat=all_features+envelope__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+envelope__target=match_mismatch__problem=binary__feat=all_features+envelope__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+envelope__target=match_mismatch__problem=multiclass__feat=all_features+envelope__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+envelope__target=match_mismatch__problem=multiclass__feat=all_features+envelope__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+envelope__target=match_mismatch_general__problem=binary__feat=all_features+envelope__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+envelope__target=match_mismatch_general__problem=binary__feat=all_features+envelope__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+envelope__target=match_mismatch_general__problem=multiclass__feat=all_features+envelope__gpu_optuna
# [envelope] rows missing after index match -> train: 1658, test: 160
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-16 13:04:15,770] A new study created in memory with name: tabr__X_name=screen+envelope__target=match_mismatch_general__problem=multiclass__feat=all_features+envelope__gpu_optuna__no_neutral
# ================================================================================
# Running: tabr__X_name=screen+envelope__target=match_mismatch_general__problem=multiclass__feat=all_features+envelope__gpu_optuna__no_neutral
# X_train: (3016, 897), X_test: (336, 897)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-16 13:04:23,161] Trial 0 finished with value: 0.5383529748006712 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.5383529748006712.
# [I 2026-04-16 13:04:39,606] Trial 1 finished with value: 0.5984287249257758 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:04:47,383] Trial 2 finished with value: 0.5599021957985482 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:05:10,140] Trial 3 finished with value: 0.5331737540376026 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:05:24,144] Trial 4 finished with value: 0.5367480346213115 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:05:39,228] Trial 5 finished with value: 0.5673616762779734 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.15723908986670418, 'dropout0': 0.35681862207084536, 'dropout1': 0.25245545039890516, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.004175380307518435, 'weight_decay': 0.0024213408972073107, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 88, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.0696029796674973}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:05:41,481] Trial 6 pruned.
# [I 2026-04-16 13:05:52,846] Trial 7 finished with value: 0.5591476644788401 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.38505936587117007, 'dropout0': 0.33439204820488233, 'dropout1': 0.2783896824374792, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.0010947002036624288, 'weight_decay': 3.5652340426862525e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 94, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.043385164923797306}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:06:06,320] Trial 8 finished with value: 0.5568041354640741 and parameters: {'d_main': 256, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 3, 'context_dropout': 0.010604524216648726, 'dropout0': 0.23431023250938532, 'dropout1': 0.37609209656998305, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.00014832651791730684, 'weight_decay': 1.167890125531533e-06, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 82, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.02820345725713065}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:06:22,934] Trial 9 finished with value: 0.5569289840264914 and parameters: {'d_main': 384, 'd_mult': 3.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.30181714963387296, 'dropout0': 0.04124954753437304, 'dropout1': 0.3610211626718267, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0009424401316515453, 'weight_decay': 0.00021734361959774786, 'batch_size': 1024, 'eval_batch_size': 512, 'max_epochs': 90, 'patience': 12, 'grad_clip': 2.0, 'label_smoothing': 0.011706701642760588}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:06:58,954] Trial 10 finished with value: 0.5887368554060235 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3945561399164252, 'dropout0': 0.05974507849646786, 'dropout1': 0.12735560982974398, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.00265790208485623, 'weight_decay': 0.00014708428299971567, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.05018794245675477}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:07:30,807] Trial 11 finished with value: 0.5752201739924441 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.39712509626059955, 'dropout0': 0.07904000679456186, 'dropout1': 0.1613812032159982, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.00424558651276101, 'weight_decay': 0.0022063664582440763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 83, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.059342324127145206}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:07:41,268] Trial 12 pruned.
# [I 2026-04-16 13:08:20,633] Trial 13 finished with value: 0.5847929850513436 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3625305346625074, 'dropout0': 0.062277910009708407, 'dropout1': 0.05604237941177269, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'adamw', 'lr': 0.0025423242554160046, 'weight_decay': 0.0005748051765001817, 'batch_size': 128, 'eval_batch_size': 256, 'max_epochs': 83, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.07558262094403141}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:08:32,877] Trial 14 finished with value: 0.5912836768336609 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3122437102461093, 'dropout0': 0.1128964869734983, 'dropout1': 0.04644482368458544, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0017841306161028542, 'weight_decay': 2.5766762099090374e-05, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 89, 'patience': 15, 'grad_clip': None, 'label_smoothing': 0.05103124128788783}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:08:41,235] Trial 15 finished with value: 0.5666914164647803 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3102329866221771, 'dropout0': 0.13250360278345885, 'dropout1': 0.1772222382181997, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0002977007882053992, 'weight_decay': 0.0001222015518570178, 'batch_size': 1024, 'eval_batch_size': 512, 'max_epochs': 88, 'patience': 17, 'grad_clip': None, 'label_smoothing': 0.04805456818628966}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:08:51,279] Trial 16 finished with value: 0.592028793393353 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.3472747634926119, 'dropout0': 0.05041546071527933, 'dropout1': 0.05022782941419018, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0011974221258591736, 'weight_decay': 0.00020315120551706243, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 92, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.03495101658368352}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:09:03,866] Trial 17 finished with value: 0.5787719066644652 and parameters: {'d_main': 192, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.21406218526842982, 'dropout0': 0.06975910010047442, 'dropout1': 0.11977277830628164, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0022599439381296525, 'weight_decay': 0.0013573676179012156, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 93, 'patience': 14, 'grad_clip': 1.0, 'label_smoothing': 0.03534053559183939}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:09:32,084] Trial 18 finished with value: 0.5778255505142627 and parameters: {'d_main': 384, 'd_mult': 2.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.386549525898094, 'dropout0': 0.006614899724325916, 'dropout1': 0.0676018219560319, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0019991785990839763, 'weight_decay': 0.0005478806949662774, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 86, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.01930236426158053}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:09:42,810] Trial 19 finished with value: 0.5814729807534675 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.3965037844768406, 'dropout0': 0.10920340198277956, 'dropout1': 0.08665964652375945, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.00226541226380743, 'weight_decay': 5.4751236751211014e-05, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 100, 'patience': 15, 'grad_clip': 1.0, 'label_smoothing': 0.05159924073426149}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:09:47,863] Trial 20 pruned.
# [I 2026-04-16 13:10:04,641] Trial 21 finished with value: 0.5797339019383959 and parameters: {'d_main': 384, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.3503605378981804, 'dropout0': 0.03310898306625834, 'dropout1': 0.07119759261286782, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.000557132819233308, 'weight_decay': 5.0778808564424454e-05, 'batch_size': 1024, 'eval_batch_size': 512, 'max_epochs': 89, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.011815888097300688}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:10:17,787] Trial 22 finished with value: 0.5890805480912844 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.22415667710069484, 'dropout0': 0.08352921670265462, 'dropout1': 0.06846196401862269, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.004728564034250624, 'weight_decay': 9.796341874906167e-05, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 90, 'patience': 15, 'grad_clip': None, 'label_smoothing': 0.06894300752997376}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:10:31,207] Trial 23 finished with value: 0.5853069720680003 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.27696886157708833, 'dropout0': 0.022606521186538758, 'dropout1': 0.06225298974835548, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0006216975860325339, 'weight_decay': 0.00029014063128811817, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 92, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.014716275951534415}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:10:55,875] Trial 24 finished with value: 0.5918974780775195 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.3452270066336063, 'dropout0': 0.09061384112411433, 'dropout1': 0.04519880598114311, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.000930479871081109, 'weight_decay': 7.548409495644138e-06, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 89, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.05322201361818499}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:11:06,872] Trial 25 finished with value: 0.584440618493337 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.36500698882876603, 'dropout0': 0.0870178703188971, 'dropout1': 0.057338639374917524, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.00473522516977528, 'weight_decay': 0.004314130864679661, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.03267459318715371}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:11:40,051] Trial 26 finished with value: 0.5837804430666858 and parameters: {'d_main': 192, 'd_mult': 1.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.36926179474623005, 'dropout0': 0.08492978330291973, 'dropout1': 0.11267962727664235, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.00024744138493172787, 'weight_decay': 2.2937707190993025e-06, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 91, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.03493828475070641}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:11:43,510] Trial 27 pruned.
# [I 2026-04-16 13:12:08,705] Trial 28 finished with value: 0.5765198656742054 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.2642775318365266, 'dropout0': 0.05953173445657246, 'dropout1': 0.028109514245797003, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.0023652990963602518, 'weight_decay': 3.0482951504324096e-06, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 89, 'patience': 15, 'grad_clip': None, 'label_smoothing': 0.0766636516230157}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:12:24,272] Trial 29 finished with value: 0.5691804122626771 and parameters: {'d_main': 384, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.3896281283314821, 'dropout0': 0.1735712061622054, 'dropout1': 0.17725106277808667, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0012559274715612059, 'weight_decay': 8.854915971051142e-06, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 13, 'grad_clip': None, 'label_smoothing': 0.05381561835180254}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:12:26,590] Trial 30 pruned.
# [I 2026-04-16 13:12:28,012] Trial 31 pruned.
# [I 2026-04-16 13:13:04,488] Trial 32 finished with value: 0.5897904604051424 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3520514161419499, 'dropout0': 0.20206741910195158, 'dropout1': 0.0072520198354515605, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0007175276375168758, 'weight_decay': 7.061281504705917e-06, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 83, 'patience': 13, 'grad_clip': None, 'label_smoothing': 0.052570403247111694}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:13:18,840] Trial 33 finished with value: 0.5880519793689762 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.30240778180782246, 'dropout0': 0.022419501004171574, 'dropout1': 0.1487820560231301, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.0032551474908997496, 'weight_decay': 0.00017171414992157668, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 89, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.013431024681640688}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:13:23,288] Trial 34 pruned.
# [I 2026-04-16 13:13:38,415] Trial 35 finished with value: 0.5849163257365628 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.31244632512197357, 'dropout0': 0.010295459628914101, 'dropout1': 0.061682396784439694, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0020679828260423854, 'weight_decay': 0.004403088437584638, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 81, 'patience': 17, 'grad_clip': 2.0, 'label_smoothing': 0.03666002340609236}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:13:42,285] Trial 36 pruned.
# [I 2026-04-16 13:13:45,579] Trial 37 pruned.
# [I 2026-04-16 13:14:04,151] Trial 38 finished with value: 0.5930350630198787 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.39538944545726235, 'dropout0': 0.047505904614049924, 'dropout1': 0.10693992362635017, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'radam', 'lr': 0.0032187158298651224, 'weight_decay': 0.002702109413338464, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 19, 'grad_clip': 1.0, 'label_smoothing': 0.047244614170266035}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:14:25,365] Trial 39 finished with value: 0.5793201629736526 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.3165845207941279, 'dropout0': 0.014994550397145208, 'dropout1': 0.17345020082462503, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.0031466965042701244, 'weight_decay': 0.0015421589177068216, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.04259448593611635}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:14:44,369] Trial 40 finished with value: 0.5955540537809831 and parameters: {'d_main': 256, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.38576373169750994, 'dropout0': 0.011372803904313042, 'dropout1': 0.02936665527178728, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0009385399486780884, 'weight_decay': 0.002103596323356005, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.06236839238739472}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:15:08,781] Trial 41 finished with value: 0.5815924548906488 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.37934623488559555, 'dropout0': 0.13459943530770443, 'dropout1': 0.10322045475554188, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'radam', 'lr': 0.002721641061272516, 'weight_decay': 0.0014053878432217267, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.02530489611548199}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:15:22,755] Trial 42 finished with value: 0.5864625242374546 and parameters: {'d_main': 256, 'd_mult': 2.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.35969249561868283, 'dropout0': 0.09150078943013244, 'dropout1': 0.0029650268947343343, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'adamw', 'lr': 0.0008531493983472248, 'weight_decay': 0.0021666706338337705, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.062402062453467445}. Best is trial 1 with value: 0.5984287249257758.
# [I 2026-04-16 13:15:45,736] Trial 43 finished with value: 0.598580852452032 and parameters: {'d_main': 256, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.3732675562478298, 'dropout0': 0.022933406591187477, 'dropout1': 0.10152751455694836, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'radam', 'lr': 0.0017313889194190705, 'weight_decay': 0.0019923665083724797, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.0573339184073867}. Best is trial 43 with value: 0.598580852452032.
# [I 2026-04-16 13:16:14,844] Trial 44 finished with value: 0.5914710730302496 and parameters: {'d_main': 256, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.38975742144408676, 'dropout0': 0.07821886775903483, 'dropout1': 0.16844297752367432, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'radam', 'lr': 0.0018816782621229307, 'weight_decay': 0.0012639372659692158, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.08494340789745815}. Best is trial 43 with value: 0.598580852452032.
# [I 2026-04-16 13:16:17,093] Trial 45 pruned.
# [I 2026-04-16 13:16:36,740] Trial 46 finished with value: 0.5836518720274724 and parameters: {'d_main': 256, 'd_mult': 2.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.36176446393447403, 'dropout0': 0.02408481399232782, 'dropout1': 0.06887921980675969, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.0003076722911213398, 'weight_decay': 0.0019947330436690855, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 85, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.0618966108152978}. Best is trial 43 with value: 0.598580852452032.
# [I 2026-04-16 13:16:55,296] Trial 47 finished with value: 0.5810097880922858 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.3143039123836497, 'dropout0': 0.02001729049554639, 'dropout1': 0.15306829522158696, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'radam', 'lr': 0.001966823992722127, 'weight_decay': 0.0011608153571907123, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 83, 'patience': 16, 'grad_clip': 5.0, 'label_smoothing': 0.037897607753413}. Best is trial 43 with value: 0.598580852452032.
# [I 2026-04-16 13:17:13,298] Trial 48 finished with value: 0.5956063228077209 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.3177133850583316, 'dropout0': 0.05983768931585064, 'dropout1': 0.007567423306839294, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'radam', 'lr': 0.002217048194263357, 'weight_decay': 0.0005421172645292435, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 87, 'patience': 18, 'grad_clip': 5.0, 'label_smoothing': 0.06024233184526527}. Best is trial 43 with value: 0.598580852452032.
# [I 2026-04-16 13:17:38,166] Trial 49 finished with value: 0.5800754061024374 and parameters: {'d_main': 256, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.3809593588385667, 'dropout0': 0.05039023397941384, 'dropout1': 0.010569352900910618, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0007902424750983771, 'weight_decay': 0.0026223105054524474, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 87, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.058091868168898705}. Best is trial 43 with value: 0.598580852452032.
# [I 2026-04-16 13:17:41,624] Trial 50 pruned.
# [I 2026-04-16 13:18:16,839] Trial 51 finished with value: 0.5985420786487088 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.3445280096133528, 'dropout0': 0.045794788742778626, 'dropout1': 0.12908506732482944, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0033281005671161397, 'weight_decay': 0.00033947122231520774, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 90, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.0413590767200748}. Best is trial 43 with value: 0.598580852452032.
# [I 2026-04-16 13:19:03,534] Trial 52 finished with value: 0.5980370094652868 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.33638226292208284, 'dropout0': 0.11823354106347231, 'dropout1': 0.10930018932146607, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0014167103463383636, 'weight_decay': 0.004834299867588635, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 92, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.023228250548748924}. Best is trial 43 with value: 0.598580852452032.
# [I 2026-04-16 13:19:37,010] Trial 53 finished with value: 0.600079058373538 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3759401901918975, 'dropout0': 0.07766390296342837, 'dropout1': 0.010979778137711532, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0043475952136924215, 'weight_decay': 0.000595965255368091, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 93, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.024337655435353742}. Best is trial 53 with value: 0.600079058373538.
# [I 2026-04-16 13:19:41,246] Trial 54 pruned.
# [I 2026-04-16 13:19:50,868] Trial 55 pruned.
# [I 2026-04-16 13:19:58,559] Trial 56 pruned.
# [I 2026-04-16 13:20:22,858] Trial 57 finished with value: 0.5955425670762824 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.36196529769942487, 'dropout0': 0.1342339307910665, 'dropout1': 0.021447251816896468, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0030461997396743893, 'weight_decay': 0.0007931713539891018, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 90, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.020400875417891262}. Best is trial 53 with value: 0.600079058373538.
# [I 2026-04-16 13:21:08,092] Trial 58 finished with value: 0.5975217650871476 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.37485605890727064, 'dropout0': 0.023131536914185548, 'dropout1': 0.029080964382924096, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.004520245398990087, 'weight_decay': 0.0027336976990717642, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 18, 'grad_clip': None, 'label_smoothing': 0.03442989588513439}. Best is trial 53 with value: 0.600079058373538.
# [I 2026-04-16 13:22:23,080] Trial 59 finished with value: 0.6117207180200844 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3419914953522769, 'dropout0': 0.10370359395298862, 'dropout1': 0.04030606413001603, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.004619928182061359, 'weight_decay': 0.003880008151952812, 'batch_size': 128, 'eval_batch_size': 256, 'max_epochs': 82, 'patience': 17, 'grad_clip': 1.0, 'label_smoothing': 0.03469048936582664}. Best is trial 59 with value: 0.6117207180200844.
#    text_set                  target       split  no_neutral  \
# 0  envelope          match_mismatch      binary       False
# 1  envelope          match_mismatch      binary        True
# 2  envelope          match_mismatch  multiclass       False
# 3  envelope          match_mismatch  multiclass        True
# 4  envelope  match_mismatch_general      binary       False
# 5  envelope  match_mismatch_general      binary        True
# 6  envelope  match_mismatch_general  multiclass       False
# 7  envelope  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.545335            0.613883
# 1            0.556036            0.607143
# 2            0.543546            0.529284
# 3            0.473210            0.473214
# 4            0.489690            0.546638
# 5            0.544407            0.619048
# 6            0.625044            0.629067
# 7            0.600311            0.604167
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...
#    text_set                  target       split  no_neutral  \
# 0  envelope          match_mismatch      binary       False
# 1  envelope          match_mismatch      binary        True
# 2  envelope          match_mismatch  multiclass       False
# 3  envelope          match_mismatch  multiclass        True
# 4  envelope  match_mismatch_general      binary       False
# 5  envelope  match_mismatch_general      binary        True
# 6  envelope  match_mismatch_general  multiclass       False
# 7  envelope  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.545335            0.613883
# 1            0.556036            0.607143
# 2            0.543546            0.529284
# 3            0.473210            0.473214
# 4            0.489690            0.546638
# 5            0.544407            0.619048
# 6            0.625044            0.629067
# 7            0.600311            0.604167
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...

# %%
# Set: freq_bands
text_freq_bands = pd.read_parquet(FTAR_FILES["freq_bands"])
print("freq_bands shape:", text_freq_bands.shape)
summary_freq_bands = run_FTAR_set_tabr("freq_bands", text_freq_bands)
summary_freq_bands
# Out:
# freq_bands shape: (4442, 18363)
# [freq_bands] text2text feature count after cleanup: 18361
# [freq_bands] rows missing after index match -> train: 1832, test: 187
# [freq_bands] UMAP compression: train/test features 18361 -> 100
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-16 13:24:03,173] A new study created in memory with name: tabr__X_name=screen+freq_bands__target=match_mismatch__problem=binary__feat=all_features+freq_bands__gpu_optuna
# ================================================================================
# Running: tabr__X_name=screen+freq_bands__target=match_mismatch__problem=binary__feat=all_features+freq_bands__gpu_optuna
# X_train: (4146, 570), X_test: (461, 570)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-16 13:24:13,558] Trial 0 finished with value: 0.49614043009938225 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.49614043009938225.
# [I 2026-04-16 13:24:30,869] Trial 1 finished with value: 0.5241234049017227 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:24:53,464] Trial 2 finished with value: 0.5208610911160522 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:25:41,958] Trial 3 finished with value: 0.5127322789314348 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:26:03,717] Trial 4 finished with value: 0.5153927321945342 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:26:21,823] Trial 5 finished with value: 0.5231658687520715 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.15723908986670418, 'dropout0': 0.35681862207084536, 'dropout1': 0.25245545039890516, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.004175380307518435, 'weight_decay': 0.0024213408972073107, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 88, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.0696029796674973}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:26:42,205] Trial 6 finished with value: 0.5208183722314136 and parameters: {'d_main': 384, 'd_mult': 2.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.32374446219140546, 'dropout0': 0.3240453578716723, 'dropout1': 0.3468289274320415, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0009604629436055072, 'weight_decay': 1.3581551746635542e-06, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 16, 'grad_clip': None, 'label_smoothing': 0.00516817211686077}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:26:58,250] Trial 7 finished with value: 0.5107606313796779 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.38505936587117007, 'dropout0': 0.33439204820488233, 'dropout1': 0.2783896824374792, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.0010947002036624288, 'weight_decay': 3.5652340426862525e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 94, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.043385164923797306}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:27:01,569] Trial 8 pruned.
# [I 2026-04-16 13:27:06,249] Trial 9 pruned.
# [I 2026-04-16 13:27:13,798] Trial 10 pruned.
# [I 2026-04-16 13:27:25,512] Trial 11 pruned.
# [I 2026-04-16 13:27:35,273] Trial 12 pruned.
# [I 2026-04-16 13:27:38,343] Trial 13 pruned.
# [I 2026-04-16 13:27:42,958] Trial 14 pruned.
# [I 2026-04-16 13:27:46,967] Trial 15 pruned.
# [I 2026-04-16 13:27:52,453] Trial 16 pruned.
# [I 2026-04-16 13:27:56,605] Trial 17 pruned.
# [I 2026-04-16 13:28:05,891] Trial 18 pruned.
# [I 2026-04-16 13:28:29,385] Trial 19 finished with value: 0.5217842814584087 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.30673380270861345, 'dropout0': 0.2847845604708715, 'dropout1': 0.159485048379515, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.00393710840748622, 'weight_decay': 0.001334218513351405, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 87, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.020140122682083254}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:28:35,357] Trial 20 pruned.
# [I 2026-04-16 13:28:42,063] Trial 21 pruned.
# [I 2026-04-16 13:28:58,552] Trial 22 finished with value: 0.5205488990458916 and parameters: {'d_main': 192, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.2550045863617299, 'dropout0': 0.1910729440550815, 'dropout1': 0.33232035951381433, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.004115788976785409, 'weight_decay': 0.004669329331810837, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 92, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.007968428201006952}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:29:04,831] Trial 23 pruned.
# [I 2026-04-16 13:29:11,359] Trial 24 pruned.
# [I 2026-04-16 13:29:20,237] Trial 25 pruned.
# [I 2026-04-16 13:29:24,822] Trial 26 pruned.
# [I 2026-04-16 13:29:29,614] Trial 27 pruned.
# [I 2026-04-16 13:29:40,124] Trial 28 pruned.
# [I 2026-04-16 13:29:44,903] Trial 29 pruned.
# [I 2026-04-16 13:29:52,219] Trial 30 pruned.
# [I 2026-04-16 13:29:58,529] Trial 31 pruned.
# [I 2026-04-16 13:30:01,520] Trial 32 pruned.
# [I 2026-04-16 13:30:51,455] Trial 33 finished with value: 0.5221552439443102 and parameters: {'d_main': 512, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.06628361037011933, 'dropout0': 0.09090468551984109, 'dropout1': 0.07646182975848097, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'radam', 'lr': 0.002732270765511351, 'weight_decay': 0.000989794375245737, 'batch_size': 128, 'eval_batch_size': 2048, 'max_epochs': 81, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.02661091916489659}. Best is trial 1 with value: 0.5241234049017227.
# [I 2026-04-16 13:30:58,177] Trial 34 pruned.
# [I 2026-04-16 13:32:04,781] Trial 35 finished with value: 0.5282403289352404 and parameters: {'d_main': 512, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.10281317734928697, 'dropout0': 0.17707913204303988, 'dropout1': 0.20435486120654067, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.0035821928479471406, 'weight_decay': 0.0028208187338845617, 'batch_size': 128, 'eval_batch_size': 2048, 'max_epochs': 81, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.01992917074611496}. Best is trial 35 with value: 0.5282403289352404.
# [I 2026-04-16 13:33:31,161] Trial 36 finished with value: 0.5237633868207372 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.13160663185871335, 'dropout0': 0.2375772845120584, 'dropout1': 0.23702124289198545, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.0031390941374996313, 'weight_decay': 0.0018282197809415244, 'batch_size': 128, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 18, 'grad_clip': 5.0, 'label_smoothing': 0.027263894677644982}. Best is trial 35 with value: 0.5282403289352404.
# [I 2026-04-16 13:33:51,846] Trial 37 pruned.
# [I 2026-04-16 13:34:01,664] Trial 38 pruned.
# [I 2026-04-16 13:34:04,581] Trial 39 pruned.
# [I 2026-04-16 13:36:47,114] Trial 40 finished with value: 0.5283423363187227 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.24143220667930962, 'dropout0': 0.13813424822821485, 'dropout1': 0.3602181804657503, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.002537664286492054, 'weight_decay': 0.0019673261991264, 'batch_size': 128, 'eval_batch_size': 2048, 'max_epochs': 83, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.018443232301335166}. Best is trial 40 with value: 0.5283423363187227.
# [I 2026-04-16 13:36:55,780] Trial 41 pruned.
# [I 2026-04-16 13:37:22,983] Trial 42 pruned.
# [I 2026-04-16 13:37:35,769] Trial 43 pruned.
# [I 2026-04-16 13:37:47,720] Trial 44 pruned.
# [I 2026-04-16 13:38:01,761] Trial 45 pruned.
# [I 2026-04-16 13:38:14,996] Trial 46 pruned.
# [I 2026-04-16 13:38:19,421] Trial 47 pruned.
# [I 2026-04-16 13:38:23,187] Trial 48 pruned.
# [I 2026-04-16 13:38:26,198] Trial 49 pruned.
# [I 2026-04-16 13:38:42,446] Trial 50 pruned.
# [I 2026-04-16 13:38:52,580] Trial 51 pruned.
# [I 2026-04-16 13:38:55,090] Trial 52 pruned.
# [I 2026-04-16 13:39:06,654] Trial 53 pruned.
# [I 2026-04-16 13:39:11,876] Trial 54 pruned.
# [I 2026-04-16 13:39:17,884] Trial 55 pruned.
# [I 2026-04-16 13:39:45,034] Trial 56 pruned.
# [I 2026-04-16 13:39:52,327] Trial 57 pruned.
# [I 2026-04-16 13:39:57,040] Trial 58 pruned.
# [I 2026-04-16 13:40:12,505] Trial 59 pruned.
# [freq_bands] rows missing after index match -> train: 1658, test: 160
# [freq_bands] UMAP compression: train/test features 18361 -> 100
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-16 13:41:51,566] A new study created in memory with name: tabr__X_name=screen+freq_bands__target=match_mismatch__problem=binary__feat=all_features+freq_bands__gpu_optuna__no_neutral
# ================================================================================
# Running: tabr__X_name=screen+freq_bands__target=match_mismatch__problem=binary__feat=all_features+freq_bands__gpu_optuna__no_neutral
# X_train: (3016, 570), X_test: (336, 570)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-16 13:41:57,693] Trial 0 finished with value: 0.5043948132929436 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.5043948132929436.
# [I 2026-04-16 13:42:10,184] Trial 1 finished with value: 0.5075298957906901 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.5075298957906901.
# [I 2026-04-16 13:42:21,347] Trial 2 finished with value: 0.5096531066857596 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 2 with value: 0.5096531066857596.
# [I 2026-04-16 13:42:53,197] Trial 3 finished with value: 0.49959657912396366 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 2 with value: 0.5096531066857596.
# [I 2026-04-16 13:43:05,046] Trial 4 finished with value: 0.5122113558246221 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 4 with value: 0.5122113558246221.
# [I 2026-04-16 13:43:11,503] Trial 5 pruned.
# [I 2026-04-16 13:43:25,603] Trial 6 pruned.
# [I 2026-04-16 13:43:39,115] Trial 7 finished with value: 0.5088473170159058 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.38505936587117007, 'dropout0': 0.33439204820488233, 'dropout1': 0.2783896824374792, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.0010947002036624288, 'weight_decay': 3.5652340426862525e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 94, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.043385164923797306}. Best is trial 4 with value: 0.5122113558246221.
# [I 2026-04-16 13:43:42,030] Trial 8 pruned.
# [I 2026-04-16 13:43:46,478] Trial 9 pruned.
# [I 2026-04-16 13:43:50,072] Trial 10 pruned.
# [I 2026-04-16 13:44:14,353] Trial 11 finished with value: 0.5127053274147728 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.12736578602403395, 'dropout0': 0.27213963855752804, 'dropout1': 0.21866110270915518, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0025884704392690585, 'weight_decay': 0.0001256754108210669, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 15, 'grad_clip': 1.0, 'label_smoothing': 0.08572589527737993}. Best is trial 11 with value: 0.5127053274147728.
# [I 2026-04-16 13:44:53,250] Trial 12 finished with value: 0.5153611749891722 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.11102527558377671, 'dropout0': 0.30488725324997623, 'dropout1': 0.2879488557415974, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.004207233898480927, 'weight_decay': 0.0004202824325825108, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 87, 'patience': 13, 'grad_clip': 2.0, 'label_smoothing': 0.07266586335387235}. Best is trial 12 with value: 0.5153611749891722.
# [I 2026-04-16 13:44:57,169] Trial 13 pruned.
# [I 2026-04-16 13:45:00,783] Trial 14 pruned.
# [I 2026-04-16 13:45:24,529] Trial 15 finished with value: 0.5146036618754624 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.15746538849672584, 'dropout0': 0.3037187835458239, 'dropout1': 0.08971820841120776, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'radam', 'lr': 0.0014228153524223812, 'weight_decay': 5.25535597261205e-05, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.07911484145914853}. Best is trial 12 with value: 0.5153611749891722.
# [I 2026-04-16 13:46:29,962] Trial 16 finished with value: 0.528683924622294 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.17352426280151406, 'dropout0': 0.3907042247431698, 'dropout1': 0.2989015601569197, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.004143068728167634, 'weight_decay': 8.719363746294527e-05, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 87, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.06747461949469907}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:46:35,700] Trial 17 pruned.
# [I 2026-04-16 13:46:44,208] Trial 18 pruned.
# [I 2026-04-16 13:46:55,330] Trial 19 pruned.
# [I 2026-04-16 13:47:55,401] Trial 20 finished with value: 0.521869981043759 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.1990316908188693, 'dropout0': 0.23439783445194196, 'dropout1': 0.24723428231774855, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0019258949481402354, 'weight_decay': 0.0005745635590662983, 'batch_size': 128, 'eval_batch_size': 256, 'max_epochs': 87, 'patience': 13, 'grad_clip': None, 'label_smoothing': 0.05243346027647179}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:48:12,284] Trial 21 pruned.
# [I 2026-04-16 13:49:22,439] Trial 22 finished with value: 0.5161194673291303 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3413601305705026, 'dropout0': 0.37752745686986844, 'dropout1': 0.32015687721813707, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0045943408503536605, 'weight_decay': 9.290736857057477e-05, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 15, 'grad_clip': None, 'label_smoothing': 0.06631778564521691}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:50:17,135] Trial 23 finished with value: 0.5221484251714013 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.20005206511600146, 'dropout0': 0.3451658619029367, 'dropout1': 0.33864381140716715, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0011203080253368433, 'weight_decay': 9.322391998795248e-05, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 16, 'grad_clip': None, 'label_smoothing': 0.07606825810061746}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:50:23,691] Trial 24 pruned.
# [I 2026-04-16 13:50:35,643] Trial 25 pruned.
# [I 2026-04-16 13:50:42,413] Trial 26 pruned.
# [I 2026-04-16 13:51:37,929] Trial 27 finished with value: 0.5147686357848866 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.12144165405350944, 'dropout0': 0.16900054961977895, 'dropout1': 0.24410194956390338, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'radam', 'lr': 0.002005565476353462, 'weight_decay': 0.0004992671121544813, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 90, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.049800332409093595}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:51:51,984] Trial 28 pruned.
# [I 2026-04-16 13:52:22,988] Trial 29 finished with value: 0.5151383524095885 and parameters: {'d_main': 192, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.09151455795502517, 'dropout0': 0.35145058426203934, 'dropout1': 0.3763172335803516, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0010920740741008907, 'weight_decay': 9.711612895711606e-05, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 84, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.05016812513342218}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:52:32,597] Trial 30 pruned.
# [I 2026-04-16 13:53:47,717] Trial 31 finished with value: 0.5259326881601626 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.34679220902878, 'dropout0': 0.3447773404271935, 'dropout1': 0.39269211428998296, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.003360771543531588, 'weight_decay': 3.3245608925559834e-05, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.03350281398260628}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:54:17,172] Trial 32 finished with value: 0.5190317005777731 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.35005390748243187, 'dropout0': 0.24079789742193103, 'dropout1': 0.3200449520187086, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.003358487591949919, 'weight_decay': 2.8954413163204506e-06, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 19, 'grad_clip': 1.0, 'label_smoothing': 0.02874797712604202}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:54:22,916] Trial 33 pruned.
# [I 2026-04-16 13:54:39,658] Trial 34 pruned.
# [I 2026-04-16 13:54:48,181] Trial 35 pruned.
# [I 2026-04-16 13:54:55,874] Trial 36 pruned.
# [I 2026-04-16 13:55:01,437] Trial 37 pruned.
# [I 2026-04-16 13:55:08,806] Trial 38 pruned.
# [I 2026-04-16 13:55:21,197] Trial 39 pruned.
# [I 2026-04-16 13:55:29,618] Trial 40 pruned.
# [I 2026-04-16 13:55:33,213] Trial 41 pruned.
# [I 2026-04-16 13:55:36,538] Trial 42 pruned.
# [I 2026-04-16 13:55:43,478] Trial 43 pruned.
# [I 2026-04-16 13:55:47,126] Trial 44 pruned.
# [I 2026-04-16 13:56:23,568] Trial 45 finished with value: 0.5139640326407491 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.35233184156590214, 'dropout0': 0.208713308917076, 'dropout1': 0.2676988437827726, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.002891295754075438, 'weight_decay': 1.4640462036838457e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 88, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.04467345799025217}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:56:34,652] Trial 46 pruned.
# [I 2026-04-16 13:56:41,442] Trial 47 pruned.
# [I 2026-04-16 13:56:46,399] Trial 48 pruned.
# [I 2026-04-16 13:57:01,890] Trial 49 pruned.
# [I 2026-04-16 13:57:07,306] Trial 50 pruned.
# [I 2026-04-16 13:57:18,852] Trial 51 pruned.
# [I 2026-04-16 13:57:21,517] Trial 52 pruned.
# [I 2026-04-16 13:57:32,639] Trial 53 pruned.
# [I 2026-04-16 13:57:52,605] Trial 54 pruned.
# [I 2026-04-16 13:57:59,196] Trial 55 pruned.
# [I 2026-04-16 13:58:08,790] Trial 56 pruned.
# [I 2026-04-16 13:58:42,773] Trial 57 finished with value: 0.5237837001362011 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.3177586246622883, 'dropout0': 0.3480930550498662, 'dropout1': 0.32232721977359235, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0009277530674508863, 'weight_decay': 0.0001005000391247748, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.06445280284891347}. Best is trial 16 with value: 0.528683924622294.
# [I 2026-04-16 13:58:48,354] Trial 58 pruned.
# [I 2026-04-16 13:58:52,018] Trial 59 pruned.
# [freq_bands] rows missing after index match -> train: 1832, test: 187
# [freq_bands] UMAP compression: train/test features 18361 -> 100
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-16 14:00:00,760] A new study created in memory with name: tabr__X_name=screen+freq_bands__target=match_mismatch__problem=multiclass__feat=all_features+freq_bands__gpu_optuna
# ================================================================================
# Running: tabr__X_name=screen+freq_bands__target=match_mismatch__problem=multiclass__feat=all_features+freq_bands__gpu_optuna
# X_train: (4146, 570), X_test: (461, 570)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-16 14:00:18,944] Trial 0 finished with value: 0.4831870191959657 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.4831870191959657.
# [I 2026-04-16 14:00:47,076] Trial 1 finished with value: 0.5752465328547662 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:01:11,731] Trial 2 finished with value: 0.4958539748595049 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:02:25,733] Trial 3 finished with value: 0.47192106756644686 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:03:05,801] Trial 4 finished with value: 0.4922466856746021 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:03:48,186] Trial 5 finished with value: 0.5495953758967593 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.15723908986670418, 'dropout0': 0.35681862207084536, 'dropout1': 0.25245545039890516, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.004175380307518435, 'weight_decay': 0.0024213408972073107, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 88, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.0696029796674973}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:04:27,758] Trial 6 finished with value: 0.5209311870569716 and parameters: {'d_main': 384, 'd_mult': 2.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.32374446219140546, 'dropout0': 0.3240453578716723, 'dropout1': 0.3468289274320415, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0009604629436055072, 'weight_decay': 1.3581551746635542e-06, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 16, 'grad_clip': None, 'label_smoothing': 0.00516817211686077}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:04:56,057] Trial 7 finished with value: 0.5459336023317577 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.38505936587117007, 'dropout0': 0.33439204820488233, 'dropout1': 0.2783896824374792, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.0010947002036624288, 'weight_decay': 3.5652340426862525e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 94, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.043385164923797306}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:05:06,001] Trial 8 pruned.
# [I 2026-04-16 14:05:15,968] Trial 9 pruned.
# [I 2026-04-16 14:06:04,858] Trial 10 finished with value: 0.5479067895090867 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3945561399164252, 'dropout0': 0.05974507849646786, 'dropout1': 0.12735560982974398, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.00265790208485623, 'weight_decay': 0.00014708428299971567, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.05018794245675477}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:07:13,787] Trial 11 finished with value: 0.5370910241818626 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 3, 'context_dropout': 0.1900370583725075, 'dropout0': 0.35370539123713424, 'dropout1': 0.24502574297036916, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0024817369768193524, 'weight_decay': 0.0003170686079405177, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 90, 'patience': 18, 'grad_clip': 5.0, 'label_smoothing': 0.07096184131327642}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:08:02,494] Trial 12 finished with value: 0.5594707460026194 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.29039210953347305, 'dropout0': 0.1547637212411611, 'dropout1': 0.1525759980267164, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.003854867867157256, 'weight_decay': 0.0003089978118159997, 'batch_size': 256, 'eval_batch_size': 512, 'max_epochs': 84, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.03392862275982489}. Best is trial 1 with value: 0.5752465328547662.
# [I 2026-04-16 14:08:10,704] Trial 13 pruned.
# [I 2026-04-16 14:08:33,229] Trial 14 finished with value: 0.5778327766244251 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.3562105434328258, 'dropout0': 0.053650706904483314, 'dropout1': 0.11057577445547506, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.004868254863926826, 'weight_decay': 0.0006933533119124225, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 86, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.037777445274472986}. Best is trial 14 with value: 0.5778327766244251.
# [I 2026-04-16 14:08:38,210] Trial 15 pruned.
# [I 2026-04-16 14:09:07,938] Trial 16 finished with value: 0.5749896410868991 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.28058090746070485, 'dropout0': 0.01025924009098702, 'dropout1': 0.1381055105732363, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'radam', 'lr': 0.0014175234935388933, 'weight_decay': 0.001773623559522107, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 90, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.01026289766760987}. Best is trial 14 with value: 0.5778327766244251.
# [I 2026-04-16 14:09:32,961] Trial 17 finished with value: 0.5788768143628934 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.3657501828184148, 'dropout0': 0.20392596419863052, 'dropout1': 0.13501007047543553, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0015137367569623915, 'weight_decay': 0.0013364191474798117, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 80, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.02607950382159642}. Best is trial 17 with value: 0.5788768143628934.
# [I 2026-04-16 14:10:05,784] Trial 18 finished with value: 0.5781460580997825 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.3477361290589017, 'dropout0': 0.21088587432000416, 'dropout1': 0.12170795049597433, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.001186460455269948, 'weight_decay': 0.0017198240323935252, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 20, 'grad_clip': 1.0, 'label_smoothing': 0.03532252774884195}. Best is trial 17 with value: 0.5788768143628934.
# [I 2026-04-16 14:10:53,594] Trial 19 finished with value: 0.5765658988558688 and parameters: {'d_main': 192, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.2152836908959285, 'dropout0': 0.2347378835522717, 'dropout1': 0.1367012522421383, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.001308583177941353, 'weight_decay': 0.0013116787818193984, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.011239560783737192}. Best is trial 17 with value: 0.5788768143628934.
# [I 2026-04-16 14:11:12,181] Trial 20 pruned.
# [I 2026-04-16 14:11:31,673] Trial 21 finished with value: 0.5732674978060173 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.33147288325556057, 'dropout0': 0.16026950233087833, 'dropout1': 0.09636944091683725, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.001542055051959031, 'weight_decay': 0.0045082547465748095, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 19, 'grad_clip': 1.0, 'label_smoothing': 0.053938904397981546}. Best is trial 17 with value: 0.5788768143628934.
# [I 2026-04-16 14:12:00,130] Trial 22 finished with value: 0.5730043506041521 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.38521033538515215, 'dropout0': 0.1341832076251162, 'dropout1': 0.04353004491383468, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.000560423426268083, 'weight_decay': 0.00015780192878865403, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 19, 'grad_clip': 1.0, 'label_smoothing': 0.026321890669991556}. Best is trial 17 with value: 0.5788768143628934.
# [I 2026-04-16 14:13:09,759] Trial 23 finished with value: 0.5758106158950929 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.22018761194905306, 'dropout0': 0.02902861591710207, 'dropout1': 0.10099344629331401, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.003101192637055763, 'weight_decay': 0.0019495901245212676, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.013560074256640627}. Best is trial 17 with value: 0.5788768143628934.
# [I 2026-04-16 14:14:06,574] Trial 24 finished with value: 0.5716662222735664 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3679744586216543, 'dropout0': 0.2500788344848719, 'dropout1': 0.21312801500792458, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.0010010002623234082, 'weight_decay': 0.0018840177684672364, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.026069522446476735}. Best is trial 17 with value: 0.5788768143628934.
# [I 2026-04-16 14:14:09,291] Trial 25 pruned.
# [I 2026-04-16 14:14:13,885] Trial 26 pruned.
# [I 2026-04-16 14:14:21,515] Trial 27 pruned.
# [I 2026-04-16 14:14:24,617] Trial 28 pruned.
# [I 2026-04-16 14:14:34,963] Trial 29 pruned.
# [I 2026-04-16 14:15:14,489] Trial 30 finished with value: 0.5696445711252714 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.37986942819308767, 'dropout0': 0.29331936627299643, 'dropout1': 0.1320069291926428, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.0010903477664125222, 'weight_decay': 0.000460089710634336, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 81, 'patience': 19, 'grad_clip': 1.0, 'label_smoothing': 0.004146947657049607}. Best is trial 17 with value: 0.5788768143628934.
# [I 2026-04-16 14:15:32,706] Trial 31 pruned.
# [I 2026-04-16 14:16:10,676] Trial 32 pruned.
# [I 2026-04-16 14:16:59,147] Trial 33 finished with value: 0.5831156742489578 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.275303313505705, 'dropout0': 0.1253495706030542, 'dropout1': 0.14089717439679014, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.004504183947673998, 'weight_decay': 0.0015404274216021972, 'batch_size': 256, 'eval_batch_size': 512, 'max_epochs': 85, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.05618496409188435}. Best is trial 33 with value: 0.5831156742489578.
# [I 2026-04-16 14:17:20,585] Trial 34 finished with value: 0.5630137381507668 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.21174406350180908, 'dropout0': 0.06042937628187377, 'dropout1': 0.09519938928747637, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.002366565182229014, 'weight_decay': 0.0017352455328875239, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 85, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.05310251294896598}. Best is trial 33 with value: 0.5831156742489578.
# [I 2026-04-16 14:17:56,532] Trial 35 pruned.
# [I 2026-04-16 14:17:59,752] Trial 36 pruned.
# [I 2026-04-16 14:18:02,571] Trial 37 pruned.
# [I 2026-04-16 14:18:07,408] Trial 38 pruned.
# [I 2026-04-16 14:18:31,166] Trial 39 finished with value: 0.57405033407088 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.3984927392798813, 'dropout0': 0.09472627312575463, 'dropout1': 0.12637925103103761, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.004853707902423501, 'weight_decay': 0.004104431934141228, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 86, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.05405103569045315}. Best is trial 33 with value: 0.5831156742489578.
# [I 2026-04-16 14:18:38,711] Trial 40 pruned.
# [I 2026-04-16 14:18:49,674] Trial 41 pruned.
# [I 2026-04-16 14:19:28,983] Trial 42 finished with value: 0.5817931746773276 and parameters: {'d_main': 192, 'd_mult': 3.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.3495149904591594, 'dropout0': 0.22020957982091302, 'dropout1': 0.17436589281737364, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'adam', 'lr': 0.0011271590261716254, 'weight_decay': 0.003090155545903499, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 83, 'patience': 17, 'grad_clip': 2.0, 'label_smoothing': 0.03140834523003491}. Best is trial 33 with value: 0.5831156742489578.
# [I 2026-04-16 14:19:33,434] Trial 43 pruned.
# [I 2026-04-16 14:19:42,429] Trial 44 pruned.
# [I 2026-04-16 14:21:03,880] Trial 45 finished with value: 0.5862452985176825 and parameters: {'d_main': 256, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.28230196756082454, 'dropout0': 0.07792117269202586, 'dropout1': 0.06954401041293107, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0029482384753764784, 'weight_decay': 0.000730223523418213, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 92, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.07071806841450903}. Best is trial 45 with value: 0.5862452985176825.
# [I 2026-04-16 14:22:14,594] Trial 46 finished with value: 0.5744007667388288 and parameters: {'d_main': 256, 'd_mult': 2.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.33872150980533106, 'dropout0': 0.11603313780616702, 'dropout1': 0.09841886734884209, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.00239533031262944, 'weight_decay': 0.004784143812133179, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 92, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.09115197227074483}. Best is trial 45 with value: 0.5862452985176825.
# [I 2026-04-16 14:23:38,982] Trial 47 finished with value: 0.5802816977076382 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.3609997168137161, 'dropout0': 0.16296784888318985, 'dropout1': 0.25132929693280265, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'adam', 'lr': 0.0004971981079784416, 'weight_decay': 0.0028699400940109788, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 80, 'patience': 19, 'grad_clip': 2.0, 'label_smoothing': 0.025824387002366625}. Best is trial 45 with value: 0.5862452985176825.
# [I 2026-04-16 14:25:20,135] Trial 48 finished with value: 0.5890004264677561 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.32601859556383145, 'dropout0': 0.22202329978607555, 'dropout1': 0.1950040303523422, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'adam', 'lr': 0.0006638299149178085, 'weight_decay': 0.0019870554783530626, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 20, 'grad_clip': 2.0, 'label_smoothing': 0.01806251291280122}. Best is trial 48 with value: 0.5890004264677561.
# [I 2026-04-16 14:26:58,995] Trial 49 finished with value: 0.582851897350454 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.36132279708370607, 'dropout0': 0.21897193738372878, 'dropout1': 0.311621919868066, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'adam', 'lr': 0.0006130291648404938, 'weight_decay': 0.002324702223407011, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 81, 'patience': 20, 'grad_clip': 2.0, 'label_smoothing': 0.001705441869039273}. Best is trial 48 with value: 0.5890004264677561.
# [I 2026-04-16 14:27:11,465] Trial 50 pruned.
# [I 2026-04-16 14:27:31,748] Trial 51 pruned.
# [I 2026-04-16 14:27:45,619] Trial 52 pruned.
# [I 2026-04-16 14:27:55,890] Trial 53 pruned.
# [I 2026-04-16 14:28:05,432] Trial 54 pruned.
# [I 2026-04-16 14:28:31,056] Trial 55 pruned.
# ...
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-16 14:57:39,528] A new study created in memory with name: tabr__X_name=screen+freq_bands__target=match_mismatch_general__problem=multiclass__feat=all_features+freq_bands__gpu_optuna
# ================================================================================
# Running: tabr__X_name=screen+freq_bands__target=match_mismatch_general__problem=multiclass__feat=all_features+freq_bands__gpu_optuna
# X_train: (4146, 570), X_test: (461, 570)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-16 14:58:03,593] Trial 0 finished with value: 0.5381736567769934 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.5381736567769934.
# [I 2026-04-16 14:58:26,478] Trial 1 finished with value: 0.6301577549180735 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.6301577549180735.
# [I 2026-04-16 14:58:49,849] Trial 2 finished with value: 0.5134903529410363 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 1 with value: 0.6301577549180735.
# [I 2026-04-16 15:00:37,717] Trial 3 finished with value: 0.4940510170663908 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 1 with value: 0.6301577549180735.
# [I 2026-04-16 15:01:04,754] Trial 4 finished with value: 0.5061478064480746 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 1 with value: 0.6301577549180735.
# [I 2026-04-16 15:01:42,180] Trial 5 finished with value: 0.6017877682493071 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.15723908986670418, 'dropout0': 0.35681862207084536, 'dropout1': 0.25245545039890516, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.004175380307518435, 'weight_decay': 0.0024213408972073107, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 88, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.0696029796674973}. Best is trial 1 with value: 0.6301577549180735.
# [I 2026-04-16 15:01:47,656] Trial 6 pruned.
# [I 2026-04-16 15:02:24,532] Trial 7 finished with value: 0.5990699344842894 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.38505936587117007, 'dropout0': 0.33439204820488233, 'dropout1': 0.2783896824374792, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.0010947002036624288, 'weight_decay': 3.5652340426862525e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 94, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.043385164923797306}. Best is trial 1 with value: 0.6301577549180735.
# [I 2026-04-16 15:02:29,231] Trial 8 pruned.
# [I 2026-04-16 15:03:11,550] Trial 9 finished with value: 0.5951224954476677 and parameters: {'d_main': 384, 'd_mult': 3.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.30181714963387296, 'dropout0': 0.04124954753437304, 'dropout1': 0.3610211626718267, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0009424401316515453, 'weight_decay': 0.00021734361959774786, 'batch_size': 1024, 'eval_batch_size': 512, 'max_epochs': 90, 'patience': 12, 'grad_clip': 2.0, 'label_smoothing': 0.011706701642760588}. Best is trial 1 with value: 0.6301577549180735.
# [I 2026-04-16 15:04:00,671] Trial 10 finished with value: 0.5848067418666336 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3945561399164252, 'dropout0': 0.05974507849646786, 'dropout1': 0.12735560982974398, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.00265790208485623, 'weight_decay': 0.00014708428299971567, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.05018794245675477}. Best is trial 1 with value: 0.6301577549180735.
# [I 2026-04-16 15:04:12,716] Trial 11 pruned.
# [I 2026-04-16 15:05:13,439] Trial 12 finished with value: 0.6372461357831414 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.29039210953347305, 'dropout0': 0.1547637212411611, 'dropout1': 0.1525759980267164, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.003854867867157256, 'weight_decay': 0.0003089978118159997, 'batch_size': 256, 'eval_batch_size': 512, 'max_epochs': 84, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.03392862275982489}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:05:17,776] Trial 13 pruned.
# [I 2026-04-16 15:05:42,660] Trial 14 finished with value: 0.6286448503895461 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.3562105434328258, 'dropout0': 0.053650706904483314, 'dropout1': 0.11057577445547506, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.004868254863926826, 'weight_decay': 0.0006933533119124225, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 86, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.037777445274472986}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:05:48,977] Trial 15 pruned.
# [I 2026-04-16 15:06:56,658] Trial 16 finished with value: 0.6325021898675316 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.1950027667083626, 'dropout0': 0.1724405278630166, 'dropout1': 0.20222659194140924, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.0033715664849189642, 'weight_decay': 0.00053568744861908, 'batch_size': 256, 'eval_batch_size': 512, 'max_epochs': 83, 'patience': 20, 'grad_clip': 2.0, 'label_smoothing': 0.042609004784901525}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:07:56,651] Trial 17 finished with value: 0.6296859548445284 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.35679646456051534, 'dropout0': 0.20501528115831055, 'dropout1': 0.3242514440781201, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'radam', 'lr': 0.0015923043792848612, 'weight_decay': 0.0008815451409891455, 'batch_size': 256, 'eval_batch_size': 512, 'max_epochs': 90, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.0162337978905035}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:08:09,027] Trial 18 pruned.
# [I 2026-04-16 15:09:03,642] Trial 19 finished with value: 0.6058087080403426 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.1471817544399086, 'dropout0': 0.14140250672501783, 'dropout1': 0.13224422238971095, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 16, 'optimizer': 'radam', 'lr': 0.0017055656941114545, 'weight_decay': 0.00014750922550868796, 'batch_size': 256, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.02588892513404307}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:10:15,976] Trial 20 finished with value: 0.6341151682235868 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.33622505518145773, 'dropout0': 0.1108242240590071, 'dropout1': 0.13448387049639157, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0018421236501073202, 'weight_decay': 0.0004645264599346361, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 85, 'patience': 17, 'grad_clip': None, 'label_smoothing': 0.021258305593846002}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:11:32,503] Trial 21 finished with value: 0.6336290389329744 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.34926176804518355, 'dropout0': 0.20075564214335384, 'dropout1': 0.024136880593157883, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0017137295086976686, 'weight_decay': 0.0013535547068512668, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 86, 'patience': 18, 'grad_clip': None, 'label_smoothing': 0.04097514783523351}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:11:49,673] Trial 22 pruned.
# [I 2026-04-16 15:12:40,941] Trial 23 finished with value: 0.6328881929570623 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 3, 'context_dropout': 0.20642729587062209, 'dropout0': 0.21296781940962964, 'dropout1': 0.09629305261177383, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0005082118980433962, 'weight_decay': 0.000849123191964401, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 85, 'patience': 18, 'grad_clip': None, 'label_smoothing': 0.05290863116327578}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:13:06,670] Trial 24 finished with value: 0.6367805561961489 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 3, 'context_dropout': 0.30018331283627103, 'dropout0': 0.2691895163607407, 'dropout1': 0.011318085135289582, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.002954228826696326, 'weight_decay': 0.0028517614549410405, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 88, 'patience': 16, 'grad_clip': None, 'label_smoothing': 0.05864002901371013}. Best is trial 12 with value: 0.6372461357831414.
# [I 2026-04-16 15:13:17,077] Trial 25 pruned.
# [I 2026-04-16 15:13:49,826] Trial 26 finished with value: 0.64593479393649 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.2895614378507863, 'dropout0': 0.2656143949657445, 'dropout1': 0.044993201925862654, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.003666371864515386, 'weight_decay': 0.0019933099328391293, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 96, 'patience': 17, 'grad_clip': None, 'label_smoothing': 0.07129713220594275}. Best is trial 26 with value: 0.64593479393649.
# [I 2026-04-16 15:13:53,954] Trial 27 pruned.
# [I 2026-04-16 15:14:24,794] Trial 28 finished with value: 0.6528090962050546 and parameters: {'d_main': 192, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.2192229336202883, 'dropout0': 0.20943174089348554, 'dropout1': 0.02805081280879647, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0043547788653139855, 'weight_decay': 0.00032517814794788395, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 95, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.0896397711630729}. Best is trial 28 with value: 0.6528090962050546.
# [I 2026-04-16 15:14:27,379] Trial 29 pruned.
# [I 2026-04-16 15:14:44,276] Trial 30 pruned.
# [I 2026-04-16 15:15:02,530] Trial 31 finished with value: 0.637393852774978 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 1, 'predictor_n_blocks': 3, 'context_dropout': 0.3040379856628838, 'dropout0': 0.23794330824399562, 'dropout1': 0.08533077982759568, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.004495184921722854, 'weight_decay': 0.0024736089992742276, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 91, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.032741815128387974}. Best is trial 28 with value: 0.6528090962050546.
# [I 2026-04-16 15:15:29,511] Trial 32 finished with value: 0.6317831169561129 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 3, 'context_dropout': 0.2353081969320266, 'dropout0': 0.25857526567169525, 'dropout1': 0.13633514997437854, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.004418112932483232, 'weight_decay': 0.0007075500583464567, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 98, 'patience': 17, 'grad_clip': 1.0, 'label_smoothing': 0.0923446805440428}. Best is trial 28 with value: 0.6528090962050546.
# [I 2026-04-16 15:15:33,732] Trial 33 pruned.
# [I 2026-04-16 15:15:42,829] Trial 34 pruned.
# [I 2026-04-16 15:15:50,003] Trial 35 pruned.
# [I 2026-04-16 15:15:57,993] Trial 36 pruned.
# [I 2026-04-16 15:16:01,953] Trial 37 pruned.
# [I 2026-04-16 15:17:36,068] Trial 38 finished with value: 0.6427057020179168 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.22206326887236907, 'dropout0': 0.23558086512239595, 'dropout1': 0.11968401542126439, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0029751791665730927, 'weight_decay': 0.0012754851244263542, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 100, 'patience': 17, 'grad_clip': None, 'label_smoothing': 0.0988094235148476}. Best is trial 28 with value: 0.6528090962050546.

# %%
# Set: PID
text_PID = pd.read_parquet(FTAR_FILES["PID"])
print("PID shape:", text_PID.shape)
summary_PID = run_FTAR_set_tabr("PID", text_PID)
summary_PID
# Out:
# PID shape: (5592, 612)
# [PID] text2text feature count after cleanup: 610
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+PID__target=match_mismatch__problem=binary__feat=all_features+PID__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+PID__target=match_mismatch__problem=binary__feat=all_features+PID__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+PID__target=match_mismatch__problem=multiclass__feat=all_features+PID__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+PID__target=match_mismatch__problem=multiclass__feat=all_features+PID__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+PID__target=match_mismatch_general__problem=binary__feat=all_features+PID__gpu_optuna
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+PID__target=match_mismatch_general__problem=binary__feat=all_features+PID__gpu_optuna__no_neutral
#
# ================================================================================
# Skipping existing experiment: tabr__X_name=screen+PID__target=match_mismatch_general__problem=multiclass__feat=all_features+PID__gpu_optuna
# [PID] rows missing after index match -> train: 1004, test: 104
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-14 10:57:38,697] A new study created in memory with name: tabr__X_name=screen+PID__target=match_mismatch_general__problem=multiclass__feat=all_features+PID__gpu_optuna__no_neutral
# ================================================================================
# Running: tabr__X_name=screen+PID__target=match_mismatch_general__problem=multiclass__feat=all_features+PID__gpu_optuna__no_neutral
# X_train: (3016, 1080), X_test: (336, 1080)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-14 10:57:49,992] Trial 0 finished with value: 0.5442200352056208 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.5442200352056208.
# [I 2026-04-14 10:58:09,801] Trial 1 finished with value: 0.6000166409453915 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 10:58:20,079] Trial 2 finished with value: 0.544259403363513 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 10:58:46,776] Trial 3 finished with value: 0.5470062866474092 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 10:58:57,945] Trial 4 finished with value: 0.5492179769467516 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 10:58:59,989] Trial 5 pruned.
# [I 2026-04-14 10:59:02,171] Trial 6 pruned.
# [I 2026-04-14 10:59:04,495] Trial 7 pruned.
# [I 2026-04-14 10:59:15,872] Trial 8 finished with value: 0.5478402581178137 and parameters: {'d_main': 256, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 3, 'context_dropout': 0.010604524216648726, 'dropout0': 0.23431023250938532, 'dropout1': 0.37609209656998305, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.00014832651791730684, 'weight_decay': 1.167890125531533e-06, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 82, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.02820345725713065}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 10:59:20,380] Trial 9 pruned.
# [I 2026-04-14 10:59:55,988] Trial 10 finished with value: 0.5768910017899292 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3945561399164252, 'dropout0': 0.05974507849646786, 'dropout1': 0.12735560982974398, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.00265790208485623, 'weight_decay': 0.00014708428299971567, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.05018794245675477}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:00:28,197] Trial 11 finished with value: 0.5716460740442582 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.39712509626059955, 'dropout0': 0.07904000679456186, 'dropout1': 0.1613812032159982, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.00424558651276101, 'weight_decay': 0.0022063664582440763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 83, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.059342324127145206}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:01:11,740] Trial 12 finished with value: 0.5866816573644165 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.32982709093296103, 'dropout0': 0.15146994791019802, 'dropout1': 0.14909628032060154, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.001857099958263517, 'weight_decay': 6.813822791771272e-05, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 80, 'patience': 18, 'grad_clip': 5.0, 'label_smoothing': 0.03591914737041467}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:01:37,088] Trial 13 finished with value: 0.5996422205901387 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.1961855324427587, 'dropout0': 0.13660648681236293, 'dropout1': 0.021631521037705166, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'adam', 'lr': 0.0025730608945544564, 'weight_decay': 0.0007341254377909726, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.024701390620112004}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:02:03,924] Trial 14 finished with value: 0.5897313336245754 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 3, 'context_dropout': 0.29427141055018485, 'dropout0': 0.02548152868809317, 'dropout1': 0.1474043269314995, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'adam', 'lr': 0.002507711108159037, 'weight_decay': 0.00048497459594190313, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 87, 'patience': 18, 'grad_clip': None, 'label_smoothing': 0.006068219952540237}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:02:08,071] Trial 15 pruned.
# [I 2026-04-14 11:02:12,041] Trial 16 pruned.
# [I 2026-04-14 11:02:27,160] Trial 17 finished with value: 0.5663690297695221 and parameters: {'d_main': 384, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.3304495420004808, 'dropout0': 0.07444386723512761, 'dropout1': 0.192296918182707, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'radam', 'lr': 0.000887328071030671, 'weight_decay': 0.00038306595429711624, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 18, 'grad_clip': None, 'label_smoothing': 0.02209343319672202}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:02:30,462] Trial 18 pruned.
# [I 2026-04-14 11:02:36,475] Trial 19 pruned.
# [I 2026-04-14 11:02:48,489] Trial 20 finished with value: 0.5901632749736078 and parameters: {'d_main': 256, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3183145925032152, 'dropout0': 0.0022442744138120377, 'dropout1': 0.08138747120254178, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.0035805949450720513, 'weight_decay': 0.002367767815267558, 'batch_size': 1024, 'eval_batch_size': 512, 'max_epochs': 92, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.01107639248179311}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:02:50,536] Trial 21 pruned.
# [I 2026-04-14 11:03:08,242] Trial 22 finished with value: 0.5834507937239917 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.28646052813994716, 'dropout0': 0.09803237666695061, 'dropout1': 0.009968247863484839, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0016446993064760508, 'weight_decay': 0.0004465008913664499, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 86, 'patience': 15, 'grad_clip': None, 'label_smoothing': 0.022459206026402737}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:03:20,867] Trial 23 finished with value: 0.5718759753604363 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.15526589947317943, 'dropout0': 0.20711923680368266, 'dropout1': 0.006399901033059945, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0023381498153163902, 'weight_decay': 0.001981382929756556, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 17, 'grad_clip': None, 'label_smoothing': 0.03518442572052745}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:03:22,708] Trial 24 pruned.
# [I 2026-04-14 11:03:35,802] Trial 25 finished with value: 0.5919400941783846 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.36500698882876603, 'dropout0': 0.0870178703188971, 'dropout1': 0.057338639374917524, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.00473522516977528, 'weight_decay': 0.004314130864679661, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.03267459318715371}. Best is trial 1 with value: 0.6000166409453915.
# [I 2026-04-14 11:03:52,745] Trial 26 finished with value: 0.6075339759705156 and parameters: {'d_main': 192, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.33769637472841124, 'dropout0': 0.08515047417902985, 'dropout1': 0.02982389094929104, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0017805469915238418, 'weight_decay': 0.0007984894646406125, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.043520165443332856}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:03:58,372] Trial 27 pruned.
# [I 2026-04-14 11:04:21,919] Trial 28 finished with value: 0.59544449817752 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.10823687400126775, 'dropout0': 0.05576466877098753, 'dropout1': 0.05517583328330795, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0017817593831917194, 'weight_decay': 0.001977444693596989, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 19, 'grad_clip': 2.0, 'label_smoothing': 0.02528577896487664}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:04:24,469] Trial 29 pruned.
# [I 2026-04-14 11:04:57,950] Trial 30 finished with value: 0.6011170434131141 and parameters: {'d_main': 192, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.34513105015294115, 'dropout0': 0.07822843565606594, 'dropout1': 0.0717258794053299, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0006420079253960156, 'weight_decay': 0.0003107719794434265, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 90, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.031059892695165233}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:05:04,433] Trial 31 pruned.
# [I 2026-04-14 11:05:40,543] Trial 32 finished with value: 0.6043475535932462 and parameters: {'d_main': 192, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.3520070675655671, 'dropout0': 0.1912517444892543, 'dropout1': 0.010518861454405337, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0005008488971800889, 'weight_decay': 0.00021295147272580952, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.03167895571484905}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:06:27,947] Trial 33 finished with value: 0.6054833736617204 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.33489937956575294, 'dropout0': 0.1656617220165007, 'dropout1': 0.03599179821314216, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'adamw', 'lr': 0.00029785817090896994, 'weight_decay': 0.000889649567494086, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 83, 'patience': 15, 'grad_clip': 5.0, 'label_smoothing': 0.023089811592389736}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:06:50,461] Trial 34 finished with value: 0.5919810178010445 and parameters: {'d_main': 192, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.38176077683087734, 'dropout0': 0.19398546238217407, 'dropout1': 0.055481710220024766, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.000913738203669824, 'weight_decay': 0.0012049396978389003, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 83, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.04864292907631344}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:06:59,811] Trial 35 pruned.
# [I 2026-04-14 11:07:04,145] Trial 36 pruned.
# [I 2026-04-14 11:08:01,857] Trial 37 finished with value: 0.6001108782799784 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.3208612284374597, 'dropout0': 0.108152270297729, 'dropout1': 0.09630563254298954, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0002251662068600056, 'weight_decay': 0.00046959616602894354, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 92, 'patience': 18, 'grad_clip': 2.0, 'label_smoothing': 0.015689708745029292}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:08:04,140] Trial 38 pruned.
# [I 2026-04-14 11:08:46,990] Trial 39 finished with value: 0.6020858986834381 and parameters: {'d_main': 192, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.25986885022050504, 'dropout0': 0.06987482104697507, 'dropout1': 0.012243364373804484, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0031593313419143155, 'weight_decay': 0.0025516857239237965, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 89, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.0523521328970087}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:09:24,296] Trial 40 finished with value: 0.5905248302099241 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.23827446270695127, 'dropout0': 0.08934568802132944, 'dropout1': 0.056640413489600826, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'adamw', 'lr': 0.00016373733522283938, 'weight_decay': 0.00034712449085391283, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 80, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.022492958402949608}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:09:30,620] Trial 41 pruned.
# [I 2026-04-14 11:09:38,987] Trial 42 pruned.
# [I 2026-04-14 11:09:40,819] Trial 43 pruned.
# [I 2026-04-14 11:10:12,229] Trial 44 finished with value: 0.594667718119265 and parameters: {'d_main': 192, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 3, 'context_dropout': 0.3283085350691914, 'dropout0': 0.10433279158576877, 'dropout1': 0.026367169195555186, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.0003001836660445194, 'weight_decay': 0.002112127439476123, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 81, 'patience': 16, 'grad_clip': 5.0, 'label_smoothing': 0.043785783922917286}. Best is trial 26 with value: 0.6075339759705156.
# [I 2026-04-14 11:10:18,988] Trial 45 pruned.
# [I 2026-04-14 11:11:04,775] Trial 46 finished with value: 0.6116196753896807 and parameters: {'d_main': 192, 'd_mult': 2.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.3609748977998658, 'dropout0': 0.061650050665887364, 'dropout1': 0.005900997825218845, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0033612233264610288, 'weight_decay': 0.002034938738715607, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 85, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.03561838066832908}. Best is trial 46 with value: 0.6116196753896807.
# [I 2026-04-14 11:11:11,521] Trial 47 pruned.
# [I 2026-04-14 11:11:13,036] Trial 48 pruned.
# [I 2026-04-14 11:11:21,092] Trial 49 pruned.
# [I 2026-04-14 11:13:22,351] Trial 50 finished with value: 0.5927232157986557 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.31774377619286553, 'dropout0': 0.0802501701682665, 'dropout1': 0.044310236777233974, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0032500990440370646, 'weight_decay': 0.004303286451251429, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 90, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.05649358389032523}. Best is trial 46 with value: 0.6116196753896807.
# [I 2026-04-14 11:13:27,872] Trial 51 pruned.
# [I 2026-04-14 11:14:13,213] Trial 52 finished with value: 0.6037188899532655 and parameters: {'d_main': 192, 'd_mult': 1.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.3248727139022216, 'dropout0': 0.0911364051754957, 'dropout1': 0.04675622427027694, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.003819229990518056, 'weight_decay': 0.0013190053235878586, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 88, 'patience': 20, 'grad_clip': 5.0, 'label_smoothing': 0.04297111442953321}. Best is trial 46 with value: 0.6116196753896807.
# [I 2026-04-14 11:14:38,433] Trial 53 finished with value: 0.5979452245962265 and parameters: {'d_main': 192, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 3, 'context_dropout': 0.37497812357547516, 'dropout0': 0.281807701549725, 'dropout1': 0.11259986523627555, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.002748778772609775, 'weight_decay': 0.0043090107619206544, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.0307904528549017}. Best is trial 46 with value: 0.6116196753896807.
# [I 2026-04-14 11:14:46,639] Trial 54 pruned.
# [I 2026-04-14 11:14:52,995] Trial 55 pruned.
# [I 2026-04-14 11:14:58,237] Trial 56 pruned.
# [I 2026-04-14 11:15:01,351] Trial 57 pruned.
# [I 2026-04-14 11:15:05,966] Trial 58 pruned.
# [I 2026-04-14 11:15:08,530] Trial 59 pruned.
#   text_set                  target       split  no_neutral  \
# 0      PID          match_mismatch      binary       False
# 1      PID          match_mismatch      binary        True
# 2      PID          match_mismatch  multiclass       False
# 3      PID          match_mismatch  multiclass        True
# 4      PID  match_mismatch_general      binary       False
# 5      PID  match_mismatch_general      binary        True
# 6      PID  match_mismatch_general  multiclass       False
# 7      PID  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.509131            0.570499
# 1            0.412698            0.559524
# 2            0.591670            0.585683
# 3            0.526278            0.526786
# 4            0.512506            0.568330
# 5            0.479882            0.556548
# 6            0.581319            0.581345
# 7            0.554460            0.556548
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...
#   text_set                  target       split  no_neutral  \
# 0      PID          match_mismatch      binary       False
# 1      PID          match_mismatch      binary        True
# 2      PID          match_mismatch  multiclass       False
# 3      PID          match_mismatch  multiclass        True
# 4      PID  match_mismatch_general      binary       False
# 5      PID  match_mismatch_general      binary        True
# 6      PID  match_mismatch_general  multiclass       False
# 7      PID  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.509131            0.570499
# 1            0.412698            0.559524
# 2            0.591670            0.585683
# 3            0.526278            0.526786
# 4            0.512506            0.568330
# 5            0.479882            0.556548
# 6            0.581319            0.581345
# 7            0.554460            0.556548
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...

# %%
# Set: stat
text_stat = pd.read_parquet(FTAR_FILES["stat"])
print("stat shape:", text_stat.shape)
summary_stat = run_FTAR_set_tabr("stat", text_stat)
summary_stat
# Out:
# stat shape: (5592, 8237)
# [stat] text2text feature count after cleanup: 8235
# [stat] rows missing after index match -> train: 1193, test: 131
# [stat] UMAP compression: train/test features 8235 -> 100
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-14 11:16:08,693] A new study created in memory with name: tabr__X_name=screen+stat__target=match_mismatch__problem=binary__feat=all_features+stat__gpu_optuna
# ================================================================================
# Running: tabr__X_name=screen+stat__target=match_mismatch__problem=binary__feat=all_features+stat__gpu_optuna
# X_train: (4146, 570), X_test: (461, 570)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-14 11:16:17,174] Trial 0 finished with value: 0.4964346509868236 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.4964346509868236.
# [I 2026-04-14 11:16:30,331] Trial 1 finished with value: 0.5023656254183245 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.5023656254183245.
# [I 2026-04-14 11:16:49,514] Trial 2 finished with value: 0.5194748356872118 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 2 with value: 0.5194748356872118.
# [I 2026-04-14 11:17:31,981] Trial 3 finished with value: 0.49632709395515334 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 2 with value: 0.5194748356872118.
# [I 2026-04-14 11:17:51,866] Trial 4 finished with value: 0.5096890057291776 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 2 with value: 0.5194748356872118.
# [I 2026-04-14 11:18:13,695] Trial 5 finished with value: 0.517235569881313 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.15723908986670418, 'dropout0': 0.35681862207084536, 'dropout1': 0.25245545039890516, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.004175380307518435, 'weight_decay': 0.0024213408972073107, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 88, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.0696029796674973}. Best is trial 2 with value: 0.5194748356872118.
# [I 2026-04-14 11:18:19,623] Trial 6 pruned.
# [I 2026-04-14 11:18:39,374] Trial 7 finished with value: 0.5199852137638126 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.38505936587117007, 'dropout0': 0.33439204820488233, 'dropout1': 0.2783896824374792, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.0010947002036624288, 'weight_decay': 3.5652340426862525e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 94, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.043385164923797306}. Best is trial 7 with value: 0.5199852137638126.
# [I 2026-04-14 11:18:43,917] Trial 8 pruned.
# [I 2026-04-14 11:18:46,761] Trial 9 pruned.
# [I 2026-04-14 11:18:51,684] Trial 10 pruned.
# [I 2026-04-14 11:18:53,389] Trial 11 pruned.
# [I 2026-04-14 11:18:56,349] Trial 12 pruned.
# [I 2026-04-14 11:18:58,421] Trial 13 pruned.
# [I 2026-04-14 11:19:02,501] Trial 14 pruned.
# [I 2026-04-14 11:19:17,158] Trial 15 finished with value: 0.5204679359795413 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.12408846746137592, 'dropout0': 0.04789671676320952, 'dropout1': 0.009132254768267345, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.004238564089801298, 'weight_decay': 0.004345254466140302, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 85, 'patience': 13, 'grad_clip': 5.0, 'label_smoothing': 0.016991157539812538}. Best is trial 15 with value: 0.5204679359795413.
# [I 2026-04-14 11:19:18,726] Trial 16 pruned.
# [I 2026-04-14 11:19:35,308] Trial 17 finished with value: 0.5150166746744022 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.22866908600223257, 'dropout0': 0.10665236878922485, 'dropout1': 0.08998986507046117, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.004139296958758525, 'weight_decay': 0.00037658877108729386, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 90, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.011986065413301574}. Best is trial 15 with value: 0.5204679359795413.
# [I 2026-04-14 11:19:39,946] Trial 18 pruned.
# [I 2026-04-14 11:19:57,785] Trial 19 finished with value: 0.5112646231738335 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 1, 'context_dropout': 0.3327751441344151, 'dropout0': 0.10775690666294219, 'dropout1': 0.06825799233612079, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037780799476241933, 'weight_decay': 0.0004743169734953651, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.03765198841476776}. Best is trial 15 with value: 0.5204679359795413.
# [I 2026-04-14 11:19:59,829] Trial 20 pruned.
# [I 2026-04-14 11:20:02,215] Trial 21 pruned.
# [I 2026-04-14 11:20:20,199] Trial 22 finished with value: 0.5253243036569235 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.09051288361883413, 'dropout0': 0.021180230531734873, 'dropout1': 0.2023809398926349, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.00417224419480588, 'weight_decay': 0.004827139703756242, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 90, 'patience': 15, 'grad_clip': 5.0, 'label_smoothing': 0.0068855244605701}. Best is trial 22 with value: 0.5253243036569235.
# [I 2026-04-14 11:20:23,307] Trial 23 pruned.
# [I 2026-04-14 11:20:27,805] Trial 24 pruned.
# [I 2026-04-14 11:20:28,914] Trial 25 pruned.
# [I 2026-04-14 11:20:30,933] Trial 26 pruned.
# [I 2026-04-14 11:20:37,281] Trial 27 finished with value: 0.5199196635402386 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 1, 'context_dropout': 0.16126700746082864, 'dropout0': 0.1250579357910494, 'dropout1': 0.2669486898554699, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adamw', 'lr': 0.0016471037587388684, 'weight_decay': 0.004360327184454262, 'batch_size': 1024, 'eval_batch_size': 256, 'max_epochs': 93, 'patience': 17, 'grad_clip': None, 'label_smoothing': 0.006936381131320358}. Best is trial 22 with value: 0.5253243036569235.
# [I 2026-04-14 11:20:41,668] Trial 28 pruned.
# [I 2026-04-14 11:20:43,347] Trial 29 pruned.
# [I 2026-04-14 11:20:49,956] Trial 30 pruned.
# [I 2026-04-14 11:20:51,384] Trial 31 pruned.
# [I 2026-04-14 11:21:00,023] Trial 32 finished with value: 0.5157534862254024 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 1, 'context_dropout': 0.23155286566447342, 'dropout0': 0.15143915258068683, 'dropout1': 0.37098121060695044, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adamw', 'lr': 0.003369901625793238, 'weight_decay': 0.0007433277486160997, 'batch_size': 1024, 'eval_batch_size': 256, 'max_epochs': 94, 'patience': 18, 'grad_clip': None, 'label_smoothing': 0.03367951384430788}. Best is trial 22 with value: 0.5253243036569235.
# [I 2026-04-14 11:21:01,891] Trial 33 pruned.
# [I 2026-04-14 11:21:03,252] Trial 34 pruned.
# [I 2026-04-14 11:21:05,799] Trial 35 pruned.
# [I 2026-04-14 11:21:25,604] Trial 36 finished with value: 0.514360258762635 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.14925136047490517, 'dropout0': 0.040222893229773876, 'dropout1': 0.09372413754457327, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'radam', 'lr': 0.00232723891961553, 'weight_decay': 0.004125157066717229, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 81, 'patience': 13, 'grad_clip': None, 'label_smoothing': 0.00385905836614955}. Best is trial 22 with value: 0.5253243036569235.
# [I 2026-04-14 11:21:29,556] Trial 37 pruned.
# [I 2026-04-14 11:21:31,759] Trial 38 pruned.
# [I 2026-04-14 11:21:36,224] Trial 39 pruned.
# [I 2026-04-14 11:21:48,286] Trial 40 finished with value: 0.5199738617261171 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 3, 'context_dropout': 0.13962335088789726, 'dropout0': 0.14622923172954927, 'dropout1': 0.3192873867416392, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'adamw', 'lr': 0.0011811544191189498, 'weight_decay': 0.0011236269504616408, 'batch_size': 1024, 'eval_batch_size': 256, 'max_epochs': 85, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.002834923335868888}. Best is trial 22 with value: 0.5253243036569235.
# [I 2026-04-14 11:21:49,976] Trial 41 pruned.
# [I 2026-04-14 11:21:52,703] Trial 42 pruned.
# [I 2026-04-14 11:22:12,457] Trial 43 finished with value: 0.5267627610710566 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.09862433689361724, 'dropout0': 0.045445205599548455, 'dropout1': 0.29332460779934333, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.002588436627189149, 'weight_decay': 0.0006176120486317223, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 89, 'patience': 15, 'grad_clip': 1.0, 'label_smoothing': 0.01989222225423638}. Best is trial 43 with value: 0.5267627610710566.
# [I 2026-04-14 11:23:02,542] Trial 44 finished with value: 0.5294245673079082 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.2058546973772551, 'dropout0': 0.09135976624816965, 'dropout1': 0.3407430071454286, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0024989278938848405, 'weight_decay': 0.0005880083323933591, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 91, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.05042403772533161}. Best is trial 44 with value: 0.5294245673079082.
# [I 2026-04-14 11:23:06,669] Trial 45 pruned.
# [I 2026-04-14 11:23:11,339] Trial 46 pruned.
# [I 2026-04-14 11:23:14,917] Trial 47 pruned.
# [I 2026-04-14 11:23:17,988] Trial 48 pruned.
# [I 2026-04-14 11:23:48,490] Trial 49 finished with value: 0.5232846561090074 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.340284052015548, 'dropout0': 0.3092231435967694, 'dropout1': 0.19815296221074763, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'adamw', 'lr': 0.0017851179485848924, 'weight_decay': 5.113943807010791e-06, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 96, 'patience': 17, 'grad_clip': 1.0, 'label_smoothing': 0.03266958369302234}. Best is trial 44 with value: 0.5294245673079082.
# [I 2026-04-14 11:23:52,340] Trial 50 pruned.
# [I 2026-04-14 11:24:01,579] Trial 51 pruned.
# [I 2026-04-14 11:24:06,222] Trial 52 pruned.
# [I 2026-04-14 11:24:08,795] Trial 53 pruned.
# [I 2026-04-14 11:24:44,150] Trial 54 finished with value: 0.514681530689387 and parameters: {'d_main': 512, 'd_mult': 4.0, 'encoder_n_blocks': 1, 'predictor_n_blocks': 2, 'context_dropout': 0.3608516820746795, 'dropout0': 0.274747363507065, 'dropout1': 0.20761979083320303, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.0009893330357395962, 'weight_decay': 1.1576160190271686e-05, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 96, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.058983248260765134}. Best is trial 44 with value: 0.5294245673079082.
# [I 2026-04-14 11:25:19,686] Trial 55 finished with value: 0.5196439713474615 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.3760394986138813, 'dropout0': 0.274930350869825, 'dropout1': 0.14143771814752099, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'adamw', 'lr': 0.0011145045816213096, 'weight_decay': 1.411640238851541e-05, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 99, 'patience': 17, 'grad_clip': 1.0, 'label_smoothing': 0.026054533267885933}. Best is trial 44 with value: 0.5294245673079082.
# [I 2026-04-14 11:25:23,691] Trial 56 pruned.
# [I 2026-04-14 11:25:32,920] Trial 57 pruned.
# [I 2026-04-14 11:25:39,968] Trial 58 pruned.
# [I 2026-04-14 11:25:41,672] Trial 59 pruned.
# [stat] rows missing after index match -> train: 1004, test: 104
# [stat] UMAP compression: train/test features 8235 -> 100
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-14 11:26:28,299] A new study created in memory with name: tabr__X_name=screen+stat__target=match_mismatch__problem=binary__feat=all_features+stat__gpu_optuna__no_neutral
# ================================================================================
# Running: tabr__X_name=screen+stat__target=match_mismatch__problem=binary__feat=all_features+stat__gpu_optuna__no_neutral
# X_train: (3016, 570), X_test: (336, 570)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-14 11:26:34,803] Trial 0 finished with value: 0.5146127082578629 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.5146127082578629.
# [I 2026-04-14 11:26:45,795] Trial 1 finished with value: 0.5315531289969064 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.5315531289969064.
# [I 2026-04-14 11:26:55,861] Trial 2 finished with value: 0.5292696839446482 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 1 with value: 0.5315531289969064.
# [I 2026-04-14 11:27:19,705] Trial 3 finished with value: 0.5048438138712141 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 1 with value: 0.5315531289969064.
# [I 2026-04-14 11:27:33,802] Trial 4 finished with value: 0.4955695672817107 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 1 with value: 0.5315531289969064.
# [I 2026-04-14 11:27:38,307] Trial 5 pruned.
# [I 2026-04-14 11:27:41,918] Trial 6 pruned.
# [I 2026-04-14 11:27:44,051] Trial 7 pruned.
# [I 2026-04-14 11:27:54,696] Trial 8 pruned.
# [I 2026-04-14 11:27:56,726] Trial 9 pruned.
# [I 2026-04-14 11:28:21,644] Trial 10 finished with value: 0.5281893899293015 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3945561399164252, 'dropout0': 0.05974507849646786, 'dropout1': 0.12735560982974398, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.00265790208485623, 'weight_decay': 0.00014708428299971567, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.05018794245675477}. Best is trial 1 with value: 0.5315531289969064.
# [I 2026-04-14 11:28:37,648] Trial 11 finished with value: 0.5323421405284525 and parameters: {'d_main': 384, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.07542246950764894, 'dropout0': 0.10161711586645106, 'dropout1': 0.025049523817679258, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.002769957572686573, 'weight_decay': 0.00015021329913563166, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 14, 'grad_clip': 1.0, 'label_smoothing': 0.03400233374960418}. Best is trial 11 with value: 0.5323421405284525.
# [I 2026-04-14 11:29:02,264] Trial 12 finished with value: 0.5392651593368123 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.10314418937245005, 'dropout0': 0.18223089435544426, 'dropout1': 0.08489076536681174, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'adam', 'lr': 0.001901574878003524, 'weight_decay': 6.937724914938807e-05, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 15, 'grad_clip': 1.0, 'label_smoothing': 0.02342742919409222}. Best is trial 12 with value: 0.5392651593368123.
# [I 2026-04-14 11:29:21,861] Trial 13 pruned.
# [I 2026-04-14 11:29:24,868] Trial 14 pruned.
# [I 2026-04-14 11:29:47,469] Trial 15 finished with value: 0.5396722293406501 and parameters: {'d_main': 384, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.09186052831391284, 'dropout0': 0.20692108416346114, 'dropout1': 0.21778772550618988, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adamw', 'lr': 0.0027672297485079357, 'weight_decay': 0.00010903132379876728, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 85, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.02607403745481151}. Best is trial 15 with value: 0.5396722293406501.
# [I 2026-04-14 11:29:50,241] Trial 16 pruned.
# [I 2026-04-14 11:30:00,552] Trial 17 pruned.
# [I 2026-04-14 11:30:03,538] Trial 18 pruned.
# [I 2026-04-14 11:30:15,648] Trial 19 finished with value: 0.5327468693845161 and parameters: {'d_main': 384, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.03579444967898029, 'dropout0': 0.23135291104494551, 'dropout1': 0.2167005115897982, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'adamw', 'lr': 0.0022761118886048294, 'weight_decay': 0.00022190144958912644, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 86, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.007676915592517038}. Best is trial 15 with value: 0.5396722293406501.
# [I 2026-04-14 11:30:18,480] Trial 20 pruned.
# [I 2026-04-14 11:30:29,193] Trial 21 pruned.
# [I 2026-04-14 11:30:31,937] Trial 22 pruned.
# [I 2026-04-14 11:30:33,976] Trial 23 pruned.
# [I 2026-04-14 11:30:37,536] Trial 24 pruned.
# [I 2026-04-14 11:30:41,141] Trial 25 pruned.
# [I 2026-04-14 11:30:43,653] Trial 26 pruned.
# [I 2026-04-14 11:30:52,585] Trial 27 pruned.
# [I 2026-04-14 11:30:54,867] Trial 28 pruned.
# [I 2026-04-14 11:30:57,497] Trial 29 pruned.
# [I 2026-04-14 11:31:29,103] Trial 30 finished with value: 0.4961536582869184 and parameters: {'d_main': 384, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.14229270625756715, 'dropout0': 0.16111016920662732, 'dropout1': 0.03447484628370026, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'adamw', 'lr': 0.004018964668964207, 'weight_decay': 0.00023797133336572106, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 12, 'grad_clip': 1.0, 'label_smoothing': 0.012602833445580441}. Best is trial 15 with value: 0.5396722293406501.
# [I 2026-04-14 11:31:31,352] Trial 31 pruned.
# [I 2026-04-14 11:31:38,720] Trial 32 pruned.
# [I 2026-04-14 11:31:40,736] Trial 33 pruned.
# [I 2026-04-14 11:32:01,859] Trial 34 finished with value: 0.5407905041648507 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.014749497481775793, 'dropout0': 0.1289752117897947, 'dropout1': 0.12002277980246137, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.004522120959279323, 'weight_decay': 0.0002223148521339128, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.040024779928794524}. Best is trial 34 with value: 0.5407905041648507.
# [I 2026-04-14 11:32:16,450] Trial 35 pruned.
# [I 2026-04-14 11:32:54,863] Trial 36 finished with value: 0.544765146864496 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.07234427728015905, 'dropout0': 0.19163180349072012, 'dropout1': 0.1569009469866092, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.003421134749399928, 'weight_decay': 0.0003316875278483267, 'batch_size': 128, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 14, 'grad_clip': 2.0, 'label_smoothing': 0.0447617313678688}. Best is trial 36 with value: 0.544765146864496.
# [I 2026-04-14 11:33:00,031] Trial 37 pruned.
# [I 2026-04-14 11:33:02,899] Trial 38 pruned.
# [I 2026-04-14 11:33:05,134] Trial 39 pruned.
# [I 2026-04-14 11:33:08,813] Trial 40 pruned.
# [I 2026-04-14 11:33:11,749] Trial 41 pruned.
# [I 2026-04-14 11:33:22,509] Trial 42 pruned.
# [I 2026-04-14 11:33:26,495] Trial 43 pruned.
# [I 2026-04-14 11:33:28,752] Trial 44 pruned.
# [I 2026-04-14 11:33:33,663] Trial 45 pruned.
# [I 2026-04-14 11:33:43,134] Trial 46 pruned.
# [I 2026-04-14 11:34:12,225] Trial 47 finished with value: 0.5457929132391336 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.06188792327073587, 'dropout0': 0.12171213548870115, 'dropout1': 0.20409568252079024, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.0030051494376354838, 'weight_decay': 0.0003155090550166899, 'batch_size': 128, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 13, 'grad_clip': 2.0, 'label_smoothing': 0.02590781572208325}. Best is trial 47 with value: 0.5457929132391336.
# [I 2026-04-14 11:34:13,339] Trial 48 pruned.
# [I 2026-04-14 11:34:57,808] Trial 49 finished with value: 0.555346205873212 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.12571357402696678, 'dropout0': 0.24677089998745969, 'dropout1': 0.2228750228943785, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.002983417696432703, 'weight_decay': 0.000669696816192227, 'batch_size': 128, 'eval_batch_size': 2048, 'max_epochs': 82, 'patience': 16, 'grad_clip': 2.0, 'label_smoothing': 0.008021298075432247}. Best is trial 49 with value: 0.555346205873212.
# [I 2026-04-14 11:35:47,678] Trial 50 finished with value: 0.5347356895698523 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.13305738789965343, 'dropout0': 0.24805767543960816, 'dropout1': 0.16833694916824093, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.0012692677770328158, 'weight_decay': 0.0012348068900533739, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 18, 'grad_clip': 2.0, 'label_smoothing': 0.025980740697882348}. Best is trial 49 with value: 0.555346205873212.
# [I 2026-04-14 11:35:53,395] Trial 51 pruned.
# [I 2026-04-14 11:35:59,769] Trial 52 pruned.
# [I 2026-04-14 11:36:05,061] Trial 53 pruned.
# [I 2026-04-14 11:36:38,949] Trial 54 finished with value: 0.5400887063291288 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.05531580760513743, 'dropout0': 0.15048650782071255, 'dropout1': 0.16389793572984623, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.003859440105405796, 'weight_decay': 0.0019859519348183184, 'batch_size': 128, 'eval_batch_size': 2048, 'max_epochs': 85, 'patience': 13, 'grad_clip': 5.0, 'label_smoothing': 0.04107259803238746}. Best is trial 49 with value: 0.555346205873212.
# [I 2026-04-14 11:36:59,454] Trial 55 pruned.
# [I 2026-04-14 11:37:04,992] Trial 56 pruned.
# [I 2026-04-14 11:37:14,404] Trial 57 pruned.
# [I 2026-04-14 11:37:19,823] Trial 58 pruned.
# [I 2026-04-14 11:37:26,724] Trial 59 pruned.
# [stat] rows missing after index match -> train: 1193, test: 131
# [stat] UMAP compression: train/test features 8235 -> 100
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# c:\Users\LEGION\miniconda3\envs\table_methods\Lib\site-packages\optuna\_experimental.py:32: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2026-04-14 11:38:05,219] A new study created in memory with name: tabr__X_name=screen+stat__target=match_mismatch__problem=multiclass__feat=all_features+stat__gpu_optuna
# ================================================================================
# Running: tabr__X_name=screen+stat__target=match_mismatch__problem=multiclass__feat=all_features+stat__gpu_optuna
# X_train: (4146, 570), X_test: (461, 570)
#   0%|          | 0/60 [00:00<?, ?it/s]
# [I 2026-04-14 11:38:31,135] Trial 0 finished with value: 0.5090505356482075 and parameters: {'d_main': 192, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.3329770563201687, 'dropout0': 0.08493564427131046, 'dropout1': 0.07272998688284026, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.00021839352923182988, 'weight_decay': 7.982478599323911e-05, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 86, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0034388521115218396}. Best is trial 0 with value: 0.5090505356482075.
# [I 2026-04-14 11:38:56,535] Trial 1 finished with value: 0.5825741739992732 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.36874969400924673, 'dropout0': 0.0353970008207678, 'dropout1': 0.07839314496765809, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0047499747713783975, 'weight_decay': 0.0007186380986530763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.03251833220267471}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:39:21,498] Trial 2 finished with value: 0.49487551827140075 and parameters: {'d_main': 256, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.010167650697638076, 'dropout0': 0.04315657079732178, 'dropout1': 0.012571674274693702, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.0037977679442478553, 'weight_decay': 0.0009754680378833336, 'batch_size': 256, 'eval_batch_size': 2048, 'max_epochs': 86, 'patience': 12, 'grad_clip': 5.0, 'label_smoothing': 0.0006952130531190704}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:40:08,990] Trial 3 finished with value: 0.46378798978973784 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10071291833014567, 'dropout0': 0.1988994023569542, 'dropout1': 0.12035132392670787, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.00025777728526856777, 'weight_decay': 0.00030634389416913234, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 97, 'patience': 14, 'grad_clip': 5.0, 'label_smoothing': 0.0016587828927856153}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:40:43,840] Trial 4 finished with value: 0.48743012797014457 and parameters: {'d_main': 512, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.10317665108606225, 'dropout0': 0.26399361841367164, 'dropout1': 0.32688888008048633, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.003214646526467847, 'weight_decay': 0.0007668956091724514, 'batch_size': 1024, 'eval_batch_size': 2048, 'max_epochs': 80, 'patience': 13, 'grad_clip': 1.0, 'label_smoothing': 0.07121792213475359}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:41:16,768] Trial 5 finished with value: 0.5109238265504523 and parameters: {'d_main': 512, 'd_mult': 1.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 4, 'context_dropout': 0.15723908986670418, 'dropout0': 0.35681862207084536, 'dropout1': 0.25245545039890516, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'radam', 'lr': 0.004175380307518435, 'weight_decay': 0.0024213408972073107, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 88, 'patience': 19, 'grad_clip': 5.0, 'label_smoothing': 0.0696029796674973}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:41:49,701] Trial 6 finished with value: 0.5130632271849105 and parameters: {'d_main': 384, 'd_mult': 2.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 2, 'context_dropout': 0.32374446219140546, 'dropout0': 0.3240453578716723, 'dropout1': 0.3468289274320415, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0009604629436055072, 'weight_decay': 1.3581551746635542e-06, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 16, 'grad_clip': None, 'label_smoothing': 0.00516817211686077}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:42:16,538] Trial 7 finished with value: 0.5612301414433444 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 1, 'predictor_n_blocks': 1, 'context_dropout': 0.38505936587117007, 'dropout0': 0.33439204820488233, 'dropout1': 0.2783896824374792, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adamw', 'lr': 0.0010947002036624288, 'weight_decay': 3.5652340426862525e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 94, 'patience': 16, 'grad_clip': 1.0, 'label_smoothing': 0.043385164923797306}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:42:30,857] Trial 8 pruned.
# [I 2026-04-14 11:43:08,049] Trial 9 finished with value: 0.5395871935226556 and parameters: {'d_main': 384, 'd_mult': 3.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.30181714963387296, 'dropout0': 0.04124954753437304, 'dropout1': 0.3610211626718267, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 48, 'optimizer': 'radam', 'lr': 0.0009424401316515453, 'weight_decay': 0.00021734361959774786, 'batch_size': 1024, 'eval_batch_size': 512, 'max_epochs': 90, 'patience': 12, 'grad_clip': 2.0, 'label_smoothing': 0.011706701642760588}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:44:21,837] Trial 10 finished with value: 0.5683797779839922 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3945561399164252, 'dropout0': 0.05974507849646786, 'dropout1': 0.12735560982974398, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adamw', 'lr': 0.00265790208485623, 'weight_decay': 0.00014708428299971567, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 81, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.05018794245675477}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:45:18,718] Trial 11 finished with value: 0.5019171737250802 and parameters: {'d_main': 512, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.39712509626059955, 'dropout0': 0.07904000679456186, 'dropout1': 0.1613812032159982, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.00424558651276101, 'weight_decay': 0.0022063664582440763, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 83, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.059342324127145206}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:46:12,519] Trial 12 finished with value: 0.5654105351255716 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 2, 'context_dropout': 0.32982709093296103, 'dropout0': 0.15146994791019802, 'dropout1': 0.14909628032060154, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.001857099958263517, 'weight_decay': 6.813822791771272e-05, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 80, 'patience': 18, 'grad_clip': 5.0, 'label_smoothing': 0.03591914737041467}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:46:22,538] Trial 13 pruned.
# [I 2026-04-14 11:46:42,454] Trial 14 finished with value: 0.5814466046823177 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3122437102461093, 'dropout0': 0.1128964869734983, 'dropout1': 0.04644482368458544, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0017841306161028542, 'weight_decay': 2.5766762099090374e-05, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 89, 'patience': 15, 'grad_clip': None, 'label_smoothing': 0.05103124128788783}. Best is trial 1 with value: 0.5825741739992732.
# [I 2026-04-14 11:46:48,472] Trial 15 pruned.
# [I 2026-04-14 11:47:04,725] Trial 16 finished with value: 0.5883948288678094 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.3472747634926119, 'dropout0': 0.05041546071527933, 'dropout1': 0.05022782941419018, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0011974221258591736, 'weight_decay': 0.00020315120551706243, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 92, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.03495101658368352}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:47:26,146] Trial 17 finished with value: 0.5760163714869566 and parameters: {'d_main': 192, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.21406218526842982, 'dropout0': 0.06975910010047442, 'dropout1': 0.11977277830628164, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0022599439381296525, 'weight_decay': 0.0013573676179012156, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 93, 'patience': 14, 'grad_clip': 1.0, 'label_smoothing': 0.03534053559183939}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:48:15,385] Trial 18 finished with value: 0.5648802493928213 and parameters: {'d_main': 384, 'd_mult': 2.5, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.386549525898094, 'dropout0': 0.006614899724325916, 'dropout1': 0.0676018219560319, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0019991785990839763, 'weight_decay': 0.0005478806949662774, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 86, 'patience': 19, 'grad_clip': None, 'label_smoothing': 0.01930236426158053}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:48:27,184] Trial 19 finished with value: 0.5722400267640768 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.3965037844768406, 'dropout0': 0.10920340198277956, 'dropout1': 0.08665964652375945, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.00226541226380743, 'weight_decay': 5.4751236751211014e-05, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 100, 'patience': 15, 'grad_clip': 1.0, 'label_smoothing': 0.05159924073426149}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:49:05,461] Trial 20 finished with value: 0.5729838325935951 and parameters: {'d_main': 384, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.32912864256850904, 'dropout0': 0.01299416872220802, 'dropout1': 0.17783968548893092, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.00107403239544697, 'weight_decay': 0.001813990315727691, 'batch_size': 256, 'eval_batch_size': 256, 'max_epochs': 84, 'patience': 18, 'grad_clip': None, 'label_smoothing': 0.027654572469847264}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:49:38,105] Trial 21 finished with value: 0.5708249859547798 and parameters: {'d_main': 384, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.3503605378981804, 'dropout0': 0.03310898306625834, 'dropout1': 0.07119759261286782, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.000557132819233308, 'weight_decay': 5.0778808564424454e-05, 'batch_size': 1024, 'eval_batch_size': 512, 'max_epochs': 89, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.011815888097300688}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:49:41,103] Trial 22 pruned.
# [I 2026-04-14 11:49:57,504] Trial 23 finished with value: 0.5876669612159676 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.27696886157708833, 'dropout0': 0.022606521186538758, 'dropout1': 0.06225298974835548, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0006216975860325339, 'weight_decay': 0.00029014063128811817, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 92, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.014716275951534415}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:50:09,120] Trial 24 finished with value: 0.5804727156553622 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 1, 'context_dropout': 0.24473243655621862, 'dropout0': 0.11762722916709156, 'dropout1': 0.017428484324669, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 32, 'optimizer': 'adam', 'lr': 0.0012958811570996762, 'weight_decay': 0.0013697103699383682, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 94, 'patience': 12, 'grad_clip': None, 'label_smoothing': 0.0357030782740962}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:50:12,363] Trial 25 pruned.
# [I 2026-04-14 11:50:28,850] Trial 26 finished with value: 0.5801203593966101 and parameters: {'d_main': 256, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.33805018944179016, 'dropout0': 0.06289713963766913, 'dropout1': 0.019053029779766816, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 48, 'optimizer': 'adamw', 'lr': 0.0016017764963070565, 'weight_decay': 0.00021387777553787316, 'batch_size': 512, 'eval_batch_size': 256, 'max_epochs': 92, 'patience': 15, 'grad_clip': None, 'label_smoothing': 0.026737857255716167}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:50:33,310] Trial 27 pruned.
# [I 2026-04-14 11:50:37,466] Trial 28 pruned.
# [I 2026-04-14 11:50:57,216] Trial 29 finished with value: 0.5828629883047498 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.3637430548376131, 'dropout0': 0.09259986439885123, 'dropout1': 0.04356778577932926, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0011266219924982216, 'weight_decay': 0.001986939485128948, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 91, 'patience': 16, 'grad_clip': None, 'label_smoothing': 0.01368188835472008}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:51:45,270] Trial 30 finished with value: 0.5879267590240539 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.3805016049036511, 'dropout0': 0.048703841337996705, 'dropout1': 0.0013273058398021106, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.0028646652490274876, 'weight_decay': 0.0011652289014574574, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 84, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.015339959603065088}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:52:35,807] Trial 31 finished with value: 0.579185773406765 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.3984067651192895, 'dropout0': 0.025546637051514717, 'dropout1': 0.007503954934723078, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0037869119864876147, 'weight_decay': 0.0017668888514646441, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 84, 'patience': 14, 'grad_clip': 1.0, 'label_smoothing': 0.04369216570447265}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:53:16,895] Trial 32 finished with value: 0.5856098897585952 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 2, 'context_dropout': 0.36554762662056917, 'dropout0': 0.1669769648345383, 'dropout1': 0.004343445700414774, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.00187995227382571, 'weight_decay': 0.0006213800049463889, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 80, 'patience': 14, 'grad_clip': None, 'label_smoothing': 0.019809014611027097}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:53:20,210] Trial 33 pruned.
# [I 2026-04-14 11:54:23,696] Trial 34 pruned.
# [I 2026-04-14 11:54:30,484] Trial 35 pruned.
# [I 2026-04-14 11:54:45,671] Trial 36 pruned.
# [I 2026-04-14 11:54:51,013] Trial 37 pruned.
# [I 2026-04-14 11:54:54,930] Trial 38 pruned.
# [I 2026-04-14 11:55:42,386] Trial 39 finished with value: 0.5837497767653381 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 1, 'context_dropout': 0.39657286954659643, 'dropout0': 0.22575797387983756, 'dropout1': 0.03347752994695043, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.0008492867497758058, 'weight_decay': 0.0003176105496112491, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 80, 'patience': 16, 'grad_clip': None, 'label_smoothing': 0.010344100648258992}. Best is trial 16 with value: 0.5883948288678094.
# [I 2026-04-14 11:55:49,881] Trial 40 pruned.
# ...
# [I 2026-04-14 13:28:57,982] Trial 17 finished with value: 0.5743904017986228 and parameters: {'d_main': 128, 'd_mult': 2.5, 'encoder_n_blocks': 3, 'predictor_n_blocks': 3, 'context_dropout': 0.37835801637182503, 'dropout0': 0.11746017808896286, 'dropout1': 0.2646778416012153, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0017783881394533038, 'weight_decay': 0.0014008860198168793, 'batch_size': 256, 'eval_batch_size': 512, 'max_epochs': 88, 'patience': 17, 'grad_clip': 1.0, 'label_smoothing': 0.01545032640287066}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:29:13,637] Trial 18 pruned.
# [I 2026-04-14 13:29:31,110] Trial 19 finished with value: 0.5785144062915248 and parameters: {'d_main': 192, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.230199192265655, 'dropout0': 0.09306785467452798, 'dropout1': 0.0824952609059984, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 8, 'optimizer': 'adam', 'lr': 0.0007398187470050346, 'weight_decay': 0.0009044044413254291, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 84, 'patience': 18, 'grad_clip': 2.0, 'label_smoothing': 0.010056192711965003}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:29:35,432] Trial 20 pruned.
# [I 2026-04-14 13:29:51,309] Trial 21 finished with value: 0.5783859246384816 and parameters: {'d_main': 128, 'd_mult': 2.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3810685010999049, 'dropout0': 0.016100061479607953, 'dropout1': 0.021332865882294785, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.00038539973892056935, 'weight_decay': 0.0005484381111764465, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 88, 'patience': 17, 'grad_clip': 2.0, 'label_smoothing': 0.009646367891817248}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:29:59,075] Trial 22 pruned.
# [I 2026-04-14 13:30:34,804] Trial 23 finished with value: 0.5888167427391682 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.29028992283801536, 'dropout0': 0.10978886798233216, 'dropout1': 0.06792363007968072, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0010516350262762871, 'weight_decay': 0.004101095002945568, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 83, 'patience': 16, 'grad_clip': 2.0, 'label_smoothing': 0.05289138049093094}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:30:40,475] Trial 24 pruned.
# [I 2026-04-14 13:30:52,353] Trial 25 finished with value: 0.5809282662260526 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.36500698882876603, 'dropout0': 0.0870178703188971, 'dropout1': 0.057338639374917524, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.00473522516977528, 'weight_decay': 0.004314130864679661, 'batch_size': 1024, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.03267459318715371}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:31:17,445] Trial 26 finished with value: 0.5872608718518769 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.36391301727569664, 'dropout0': 0.029899602023960817, 'dropout1': 0.07472489732054258, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0003724540700831256, 'weight_decay': 6.268797986900544e-05, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 85, 'patience': 20, 'grad_clip': 2.0, 'label_smoothing': 0.030968636388411748}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:31:33,165] Trial 27 pruned.
# [I 2026-04-14 13:32:02,971] Trial 28 finished with value: 0.5776392695526167 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.1960381053724285, 'dropout0': 0.04027720971744295, 'dropout1': 0.07872879151446645, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 16, 'optimizer': 'adam', 'lr': 0.000844559087811882, 'weight_decay': 0.0033377819567142132, 'batch_size': 128, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 16, 'grad_clip': 2.0, 'label_smoothing': 0.05039730664369405}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:32:26,409] Trial 29 finished with value: 0.5819304147956245 and parameters: {'d_main': 384, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.39170565417722086, 'dropout0': 0.12758319581754368, 'dropout1': 0.20109480749862, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0005305959166850988, 'weight_decay': 5.687151261990171e-05, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 83, 'patience': 19, 'grad_clip': 2.0, 'label_smoothing': 0.03319199895824154}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:32:42,080] Trial 30 pruned.
# [I 2026-04-14 13:32:58,535] Trial 31 pruned.
# [I 2026-04-14 13:33:34,079] Trial 32 finished with value: 0.5762601975900828 and parameters: {'d_main': 384, 'd_mult': 2.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.27149479432780355, 'dropout0': 0.2637119524288226, 'dropout1': 0.03670187960965403, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0011172701433606316, 'weight_decay': 0.004351201118817883, 'batch_size': 128, 'eval_batch_size': 256, 'max_epochs': 87, 'patience': 15, 'grad_clip': 2.0, 'label_smoothing': 0.04643894806753001}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:33:36,933] Trial 33 pruned.
# [I 2026-04-14 13:33:55,124] Trial 34 finished with value: 0.5841288425577555 and parameters: {'d_main': 128, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 3, 'context_dropout': 0.3875453062599024, 'dropout0': 0.15372984922574612, 'dropout1': 0.08276005077213962, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0018861895742928615, 'weight_decay': 0.0011258569980764055, 'batch_size': 512, 'eval_batch_size': 512, 'max_epochs': 82, 'patience': 20, 'grad_clip': None, 'label_smoothing': 0.03828596013640896}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:34:10,123] Trial 35 finished with value: 0.5869630397524384 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3882977715405736, 'dropout0': 0.07257984743022117, 'dropout1': 0.028695889260962937, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.001319307328388387, 'weight_decay': 0.0019501029169969213, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 18, 'grad_clip': 2.0, 'label_smoothing': 0.04563075867567185}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:34:30,545] Trial 36 finished with value: 0.5856974523885545 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 2, 'predictor_n_blocks': 4, 'context_dropout': 0.38676290940933783, 'dropout0': 0.11552798211507061, 'dropout1': 0.18810967855705873, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0011679411518632549, 'weight_decay': 0.0008284910040324547, 'batch_size': 512, 'eval_batch_size': 1024, 'max_epochs': 82, 'patience': 20, 'grad_clip': 2.0, 'label_smoothing': 0.06757028020305594}. Best is trial 14 with value: 0.5889586282539727.
# [I 2026-04-14 13:35:26,689] Trial 37 finished with value: 0.5892823843176902 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.2811164510694798, 'dropout0': 0.13344754484768673, 'dropout1': 0.09367259028982698, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.00035802668356517815, 'weight_decay': 0.0021647099195593322, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 86, 'patience': 17, 'grad_clip': 2.0, 'label_smoothing': 0.034722640330851234}. Best is trial 37 with value: 0.5892823843176902.
# [I 2026-04-14 13:35:38,452] Trial 38 pruned.
# [I 2026-04-14 13:35:40,907] Trial 39 pruned.
# [I 2026-04-14 13:35:50,981] Trial 40 pruned.
# [I 2026-04-14 13:35:55,100] Trial 41 pruned.
# [I 2026-04-14 13:36:13,119] Trial 42 pruned.
# [I 2026-04-14 13:36:41,966] Trial 43 finished with value: 0.5802021617272366 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.26142334132599326, 'dropout0': 0.13877057091246897, 'dropout1': 0.010997358214163762, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 16, 'optimizer': 'adamw', 'lr': 0.002734378283806314, 'weight_decay': 0.0015851656435722685, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 84, 'patience': 16, 'grad_clip': 2.0, 'label_smoothing': 0.03640372769349435}. Best is trial 37 with value: 0.5892823843176902.
# [I 2026-04-14 13:36:59,826] Trial 44 finished with value: 0.5853761980179846 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 3, 'predictor_n_blocks': 4, 'context_dropout': 0.3323736122173814, 'dropout0': 0.08352414585160686, 'dropout1': 0.06938761593938136, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.00146495565244422, 'weight_decay': 0.0007339103170201847, 'batch_size': 256, 'eval_batch_size': 1024, 'max_epochs': 84, 'patience': 18, 'grad_clip': 1.0, 'label_smoothing': 0.05612216311017004}. Best is trial 37 with value: 0.5892823843176902.
# [I 2026-04-14 13:37:09,062] Trial 45 pruned.
# [I 2026-04-14 13:37:15,168] Trial 46 pruned.
# [I 2026-04-14 13:37:16,961] Trial 47 pruned.
# [I 2026-04-14 13:37:31,516] Trial 48 finished with value: 0.5854468912097122 and parameters: {'d_main': 128, 'd_mult': 3.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3213903614570043, 'dropout0': 0.0031360202605568693, 'dropout1': 0.042215192064904886, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0009059048997507671, 'weight_decay': 0.00043653053975074494, 'batch_size': 512, 'eval_batch_size': 2048, 'max_epochs': 81, 'patience': 20, 'grad_clip': 2.0, 'label_smoothing': 0.026634193810436073}. Best is trial 37 with value: 0.5892823843176902.
# [I 2026-04-14 13:37:38,996] Trial 49 pruned.
# [I 2026-04-14 13:38:29,307] Trial 50 finished with value: 0.5928596643039332 and parameters: {'d_main': 256, 'd_mult': 1.5, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3599999289647085, 'dropout0': 0.059978343768364195, 'dropout1': 0.09679520946290086, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 24, 'optimizer': 'adamw', 'lr': 0.0005823418444174733, 'weight_decay': 0.0013692749887463124, 'batch_size': 128, 'eval_batch_size': 512, 'max_epochs': 85, 'patience': 17, 'grad_clip': 5.0, 'label_smoothing': 0.017435318867803643}. Best is trial 50 with value: 0.5928596643039332.
# [I 2026-04-14 13:38:39,158] Trial 51 pruned.
# [I 2026-04-14 13:39:26,331] Trial 52 finished with value: 0.5955243842532894 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.3714692665259628, 'dropout0': 0.014049527794697262, 'dropout1': 0.03658634674486965, 'normalization': 'LayerNorm', 'activation': 'GELU', 'k_neighbors': 24, 'optimizer': 'adam', 'lr': 0.0006166997806893427, 'weight_decay': 8.416797926287704e-05, 'batch_size': 128, 'eval_batch_size': 256, 'max_epochs': 95, 'patience': 19, 'grad_clip': 2.0, 'label_smoothing': 0.05239402095355384}. Best is trial 52 with value: 0.5955243842532894.
# [I 2026-04-14 13:39:34,234] Trial 53 pruned.
# [I 2026-04-14 13:39:40,782] Trial 54 pruned.
# [I 2026-04-14 13:40:25,758] Trial 55 finished with value: 0.5917474472004685 and parameters: {'d_main': 128, 'd_mult': 4.0, 'encoder_n_blocks': 4, 'predictor_n_blocks': 4, 'context_dropout': 0.291356201739278, 'dropout0': 0.09282958759471835, 'dropout1': 0.11261835485628655, 'normalization': 'LayerNorm', 'activation': 'ReLU', 'k_neighbors': 64, 'optimizer': 'adam', 'lr': 0.0008802753872060073, 'weight_decay': 0.0014836228577996702, 'batch_size': 128, 'eval_batch_size': 256, 'max_epochs': 95, 'patience': 19, 'grad_clip': 2.0, 'label_smoothing': 0.04795865842773662}. Best is trial 52 with value: 0.5955243842532894.
# [I 2026-04-14 13:40:33,513] Trial 56 pruned.
# [I 2026-04-14 13:40:38,143] Trial 57 pruned.
# [I 2026-04-14 13:40:44,377] Trial 58 pruned.
# [I 2026-04-14 13:41:04,243] Trial 59 pruned.
#   text_set                  target       split  no_neutral  \
# 0     stat          match_mismatch      binary       False
# 1     stat          match_mismatch      binary        True
# 2     stat          match_mismatch  multiclass       False
# 3     stat          match_mismatch  multiclass        True
# 4     stat  match_mismatch_general      binary       False
# 5     stat  match_mismatch_general      binary        True
# 6     stat  match_mismatch_general  multiclass       False
# 7     stat  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.427984            0.529284
# 1            0.435704            0.476190
# 2            0.580387            0.568330
# 3            0.452381            0.452381
# 4            0.575839            0.622560
# 5            0.510204            0.595238
# 6            0.662470            0.659436
# 7            0.642384            0.645833
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...
#   text_set                  target       split  no_neutral  \
# 0     stat          match_mismatch      binary       False
# 1     stat          match_mismatch      binary        True
# 2     stat          match_mismatch  multiclass       False
# 3     stat          match_mismatch  multiclass        True
# 4     stat  match_mismatch_general      binary       False
# 5     stat  match_mismatch_general      binary        True
# 6     stat  match_mismatch_general  multiclass       False
# 7     stat  match_mismatch_general  multiclass        True
#
#    tabr_test_macro_f1  tabr_test_accuracy  \
# 0            0.427984            0.529284
# 1            0.435704            0.476190
# 2            0.580387            0.568330
# 3            0.452381            0.452381
# 4            0.575839            0.622560
# 5            0.510204            0.595238
# 6            0.662470            0.659436
# 7            0.642384            0.645833
#
#                                                 file
# 0  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7  C:\Users\LEGION\Projects\CB_exepriment\dataset...

# %%
all_summaries = [
    summary_corr,
    summary_cov_freq,
    summary_envelope,
    summary_freq_bands,
    summary_PID,
    summary_stat,
]
all_results = pd.concat(all_summaries, ignore_index=True)
all_results
# Out:
#       text_set                  target       split  no_neutral  \
# 0         corr          match_mismatch      binary       False
# 1         corr          match_mismatch      binary        True
# 2         corr          match_mismatch  multiclass       False
# 3         corr          match_mismatch  multiclass        True
# 4         corr  match_mismatch_general      binary       False
# 5         corr  match_mismatch_general      binary        True
# 6         corr  match_mismatch_general  multiclass       False
# 7         corr  match_mismatch_general  multiclass        True
# 8     cov_freq          match_mismatch      binary       False
# 9     cov_freq          match_mismatch      binary        True
# 10    cov_freq          match_mismatch  multiclass       False
# 11    cov_freq          match_mismatch  multiclass        True
# 12    cov_freq  match_mismatch_general      binary       False
# 13    cov_freq  match_mismatch_general      binary        True
# 14    cov_freq  match_mismatch_general  multiclass       False
# 15    cov_freq  match_mismatch_general  multiclass        True
# 16    envelope          match_mismatch      binary       False
# 17    envelope          match_mismatch      binary        True
# 18    envelope          match_mismatch  multiclass       False
# 19    envelope          match_mismatch  multiclass        True
# 20    envelope  match_mismatch_general      binary       False
# 21    envelope  match_mismatch_general      binary        True
# 22    envelope  match_mismatch_general  multiclass       False
# 23    envelope  match_mismatch_general  multiclass        True
# 24  freq_bands          match_mismatch      binary       False
# 25  freq_bands          match_mismatch      binary        True
# 26  freq_bands          match_mismatch  multiclass       False
# 27  freq_bands          match_mismatch  multiclass        True
# 28  freq_bands  match_mismatch_general      binary       False
# 29  freq_bands  match_mismatch_general      binary        True
# 30  freq_bands  match_mismatch_general  multiclass       False
# 31  freq_bands  match_mismatch_general  multiclass        True
# 32         PID          match_mismatch      binary       False
# 33         PID          match_mismatch      binary        True
# 34         PID          match_mismatch  multiclass       False
# 35         PID          match_mismatch  multiclass        True
# 36         PID  match_mismatch_general      binary       False
# 37         PID  match_mismatch_general      binary        True
# 38         PID  match_mismatch_general  multiclass       False
# 39         PID  match_mismatch_general  multiclass        True
# 40        stat          match_mismatch      binary       False
# 41        stat          match_mismatch      binary        True
# 42        stat          match_mismatch  multiclass       False
# 43        stat          match_mismatch  multiclass        True
# 44        stat  match_mismatch_general      binary       False
# 45        stat  match_mismatch_general      binary        True
# 46        stat  match_mismatch_general  multiclass       False
# 47        stat  match_mismatch_general  multiclass        True
#
#     tabr_test_macro_f1  tabr_test_accuracy  \
# 0             0.508172            0.550976
# 1             0.425768            0.538690
# 2             0.567961            0.555315
# 3             0.544316            0.544643
# 4             0.506735            0.577007
# 5             0.477679            0.535714
# 6             0.649632            0.650759
# 7             0.582120            0.589286
# 8             0.492957            0.548807
# 9             0.468639            0.577381
# 10            0.552524            0.535792
# 11            0.498864            0.500000
# 12            0.557298            0.622560
# 13            0.559892            0.654762
# 14            0.621884            0.622560
# 15            0.520323            0.526786
# 16            0.499941            0.581345
# 17            0.403539            0.520833
# 18            0.535088            0.524946
# 19            0.502972            0.502976
# 20            0.552176            0.609544
# 21            0.538310            0.601190
# 22            0.587256            0.583514
# 23            0.603547            0.607143
# 24            0.444435            0.503254
# 25            0.485601            0.592262
# 26            0.555486            0.537961
# 27            0.494224            0.497024
# 28            0.527205            0.581345
# 29            0.547881            0.642857
# 30            0.693793            0.687636
# 31            0.663218            0.666667
# 32            0.509131            0.570499
# 33            0.412698            0.559524
# 34            0.591670            0.585683
# 35            0.526278            0.526786
# 36            0.512506            0.568330
# 37            0.479882            0.556548
# 38            0.581319            0.581345
# 39            0.554460            0.556548
# 40            0.427984            0.529284
# 41            0.435704            0.476190
# 42            0.580387            0.568330
# 43            0.452381            0.452381
# 44            0.575839            0.622560
# 45            0.510204            0.595238
# 46            0.662470            0.659436
# 47            0.642384            0.645833
#
#                                                  file
# 0   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 1   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 2   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 3   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 4   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 5   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 6   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 7   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 8   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 9   C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 10  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 11  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 12  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 13  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 14  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 15  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 16  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 17  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 18  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 19  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 20  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 21  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 22  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 23  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 24  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 25  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 26  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 27  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 28  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 29  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 30  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 31  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 32  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 33  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 34  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 35  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 36  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 37  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 38  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 39  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 40  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 41  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 42  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 43  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 44  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 45  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 46  C:\Users\LEGION\Projects\CB_exepriment\dataset...
# 47  C:\Users\LEGION\Projects\CB_exepriment\dataset...

# %%
summary_path = OUT_DIR / "summary_eye_text2text_tabr.csv"
all_results.to_csv(summary_path, index=False)
print("Saved summary:", summary_path)

all_results.groupby(["text_set", "target", "split"], as_index=False)[["tabr_test_macro_f1", "tabr_test_accuracy"]].mean()
# Out:
# Saved summary: C:\Users\LEGION\Projects\CB_exepriment\dataset_v2\optuna_results_eye_text2text_tabr\summary_eye_text2text_tabr.csv
#       text_set                  target       split  tabr_test_macro_f1  \
# 0          PID          match_mismatch      binary            0.460915
# 1          PID          match_mismatch  multiclass            0.558974
# 2          PID  match_mismatch_general      binary            0.496194
# 3          PID  match_mismatch_general  multiclass            0.567889
# 4         corr          match_mismatch      binary            0.466970
# 5         corr          match_mismatch  multiclass            0.556139
# 6         corr  match_mismatch_general      binary            0.492207
# 7         corr  match_mismatch_general  multiclass            0.615876
# 8     cov_freq          match_mismatch      binary            0.480798
# 9     cov_freq          match_mismatch  multiclass            0.525694
# 10    cov_freq  match_mismatch_general      binary            0.558595
# 11    cov_freq  match_mismatch_general  multiclass            0.571104
# 12    envelope          match_mismatch      binary            0.451740
# 13    envelope          match_mismatch  multiclass            0.519030
# 14    envelope  match_mismatch_general      binary            0.545243
# 15    envelope  match_mismatch_general  multiclass            0.595401
# 16  freq_bands          match_mismatch      binary            0.465018
# 17  freq_bands          match_mismatch  multiclass            0.524855
# 18  freq_bands  match_mismatch_general      binary            0.537543
# 19  freq_bands  match_mismatch_general  multiclass            0.678506
# 20        stat          match_mismatch      binary            0.431844
# 21        stat          match_mismatch  multiclass            0.516384
# 22        stat  match_mismatch_general      binary            0.543021
# 23        stat  match_mismatch_general  multiclass            0.652427
#
#     tabr_test_accuracy
# 0             0.565011
# 1             0.556235
# 2             0.562439
# 3             0.568946
# 4             0.544833
# 5             0.549979
# 6             0.556360
# 7             0.620022
# 8             0.563094
# 9             0.517896
# 10            0.638661
# 11            0.574673
# 12            0.551089
# 13            0.513961
# 14            0.605367
# 15            0.595328
# 16            0.547758
# 17            0.517492
# 18            0.612101
# 19            0.677151
# 20            0.502737
# 21            0.510355
# 22            0.608899
# 23            0.652635
